# %%
# import standard python libraries
import matplotlib as mpl
# %matplotlib inline
mpl.rcParams['figure.dpi'] = 96
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os, subprocess
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# import libraries for biological data analysis
from coolpuppy import coolpup
from coolpuppy.lib import numutils
from coolpuppy.lib.puputils import divide_pups
from coolpuppy import plotpup
import cooler
import bioframe
import cooltools
from cooltools import expected_cis, expected_trans
from cooltools.lib import plotting

# %cd /home/varshini/uc_analyses/
import utils
# %cd /home/varshini/LoopCall_Analysis_Scripts

# plot formatting
plt.rcParams.update({
    "text.usetex": False})
plt.rcParams['svg.fonttype'] = 'none'
plt.rc('pdf',fonttype = 42)
plt.rcParams["ps.useafm"] = True
# Out:
# /home/varshini/uc_analyses
# /home/varshini/LoopCall_Analysis_Scripts

# %%
datapath = '/mnt/md0/varshini/Analysis/Blood/complete_analyses/matchmakers/'
savedir = '/mnt/md0/varshini/Analysis/Blood/figs_v2/supp13'

if not os.path.exists(savedir):
    os.mkdir(savedir)

# %%
expdir = os.path.join('/mnt/md0/varshini/Analysis/Blood', 'microc_expected')

phases = ['AAVS1_P3', 'NFE2_P3']
dists = [25000, 50000, 100000, 200000]

type_use= 'erythroid_tf_acrs_all'
peak_use = 'enhancernotpromoternotctcf'

cooler_path = '/mnt/md1/varshini/sankaran_tfko_microc/full_merged_files/'
cooler_names = [os.path.join(cooler_path, f"{p}_microc.50.mcool::resolutions/5000") for p in phases]

phase_clrs = [cooler.Cooler(c) for c in cooler_names]
exps = [os.path.join(expdir, f"P_s_{phase}_5000bp_hg38arms.tsv") for phase in phases]

# %%
hg38_chromsizes = bioframe.fetch_chromsizes('hg38')
hg38_cens = bioframe.fetch_centromeres('hg38')
    # create a view with chromosome arms using chromosome sizes and definition of centromeres
hg38_arms = bioframe.make_chromarms(hg38_chromsizes,  hg38_cens)

    # select only those chromosomes available in cooler
hg38_arms = hg38_arms[hg38_arms.chrom.isin(phase_clrs[0].chromnames)].reset_index(drop=True)
hg38_arms = hg38_arms[~hg38_arms["chrom"].isin(['chrY','chrM'])]

# %%
subdir = 'nfe2_only_tf_100kb_merge10.0kb_clus.bed'
track = pd.read_csv(os.path.join(datapath, subdir), sep='\t')
import ast
list_cols = ['crosser_loop_scores_P2', 'crosser_loop_classes_P2', 'crosser_loop_coords_P2',
            'ss_loop_scores_P2', 'ss_loop_classes_P2', 'ss_loop_coords_P2',
            'crosser_loop_scores_P1', 'crosser_loop_classes_P1', 'crosser_loop_coords_P1',
            'ss_loop_scores_P1', 'ss_loop_classes_P1', 'ss_loop_coords_P1']
track[list_cols] = track[list_cols].applymap(ast.literal_eval)

# %%
track.columns
# Out:
# Index(['chr', 'coord', 'perturbation_name', 'triangle_score_P1',
#        'crosser_loop_scores_P1', 'crosser_loop_classes_P1',
#        'crosser_loop_coords_P1', 'ss_loop_scores_P1', 'ss_loop_classes_P1',
#        'ss_loop_coords_P1', 'agg_crosser_score_P1', 'agg_ss_score_P1',
#        'mean_crosser_score_P1', 'mean_ss_score_P1', 'triangle_score_P2',
#        'crosser_loop_scores_P2', 'crosser_loop_classes_P2',
#        'crosser_loop_coords_P2', 'ss_loop_scores_P2', 'ss_loop_classes_P2',
#        'ss_loop_coords_P2', 'agg_crosser_score_P2', 'agg_ss_score_P2',
#        'mean_crosser_score_P2', 'mean_ss_score_P2', 'quant', 'chr_diff',
#        'quant_diff'],
#       dtype='object')

# %%
track_base = subdir.split('.')[0]
print(track_base)
# Out:
# nfe2_only_tf_100kb_merge10

# %%
track[track['quant'].isna()]
# Out:
# Empty DataFrame
# Columns: [chr, coord, perturbation_name, triangle_score_P1, crosser_loop_scores_P1, crosser_loop_classes_P1, crosser_loop_coords_P1, ss_loop_scores_P1, ss_loop_classes_P1, ss_loop_coords_P1, agg_crosser_score_P1, agg_ss_score_P1, mean_crosser_score_P1, mean_ss_score_P1, triangle_score_P2, crosser_loop_scores_P2, crosser_loop_classes_P2, crosser_loop_coords_P2, ss_loop_scores_P2, ss_loop_classes_P2, ss_loop_coords_P2, agg_crosser_score_P2, agg_ss_score_P2, mean_crosser_score_P2, mean_ss_score_P2, quant, chr_diff, quant_diff]
# Index: []
#
# [0 rows x 28 columns]

# %%
# 100 kb 

track_sub = track[track['quant_diff'].isin([2, 3])]
track_sub['chrom'] = track_sub['chr']
track_sub['start'] = track_sub['coord']-100
track_sub['end'] = track_sub['coord']+100
    
for p in [0, 1]:
    clr = phase_clrs[p]
    exp0 =  pd.read_csv(exps[p], sep='\t')
    
    pup = coolpup.pileup(clr, track_sub, features_format='bed', local=True, view_df=hg38_arms,
                                        flank=200_000, expected_df = exp0, min_diag=0, nproc=8)
    fg = plotpup.plot(pup,
                             score=False, cmap='coolwarm', scale='log', sym=True,
                             height=5, vmax=2)

    
    fg.savefig(os.path.join(savedir, f"{track_base}_p{p+1}_MMs.svg"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2562392/1368267368.py in <module>
#      10     exp0 =  pd.read_csv(exps[p], sep='\t')
#      11
# ---> 12     pup = coolpup.pileup(clr, track_sub, features_format='bed', local=True, view_df=hg38_arms,
#      13                                         flank=200_000, expected_df = exp0, min_diag=0, nproc=8)
#      14     fg = plotpup.plot(pup,
#
# ~/anaconda3/lib/python3.9/site-packages/coolpuppy/coolpup.py in pileup(clr, features, features_format, view_df, expected_df, expected_value_col, clr_weight_name, flank, minshift, maxshift, nshifts, ooe, mindist, maxdist, min_diag, subset, by_window, by_strand, by_distance, groupby, ignore_group_order, flip_negative_strand, local, coverage_norm, trans, rescale, rescale_flank, rescale_size, store_stripes, nproc, seed)
#    2172     )
#    2173
# -> 2174     PU = PileUpper(
#    2175         clr=clr,
#    2176         CC=CC,
#
# ~/anaconda3/lib/python3.9/site-packages/coolpuppy/coolpup.py in __init__(self, clr, CC, view_df, clr_weight_name, expected, expected_value_col, ooe, control, coverage_norm, rescale, rescale_size, flip_negative_strand, ignore_diags, store_stripes, nproc)
#     900                 except Exception as e:
#     901                     raise ValueError("provided expected is not valid") from e
# --> 902                 self.ExpSnipper = snipping.ExpectedSnipper(
#     903                     self.clr,
#     904                     self.expected,
#
# ~/anaconda3/lib/python3.9/site-packages/cooltools/api/snipping.py in __init__(self, clr, expected, view_df, min_diag, expected_value_col)
#     705             # Make sure view_df is a proper viewframe
#     706             try:
# --> 707                 _ = is_compatible_viewframe(
#     708                     view_df,
#     709                     clr,
#
# ~/anaconda3/lib/python3.9/site-packages/cooltools/lib/checks.py in is_compatible_viewframe(view_df, verify_cooler, check_sorting, raise_errors)
#     442
#     443         # is view_df contained inside cooler-chromosomes ?
# --> 444         cooler_view = make_cooler_view(verify_cooler)
#     445         if not bioframe.is_contained(view_df, cooler_view, raise_errors=False):
#     446             raise ValueError(
#
# ~/anaconda3/lib/python3.9/site-packages/cooltools/lib/common.py in make_cooler_view(clr, ucsc_names)
#     348     else:
#     349         # rename back to short chromnames
# --> 350         cooler_view["name"] = cooler_view["chrom"]
#     351         return cooler_view
#     352
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3978         else:
#    3979             # set column
# -> 3980             self._set_item(key, value)
#    3981
#    3982     def _setitem_slice(self, key: slice, value):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4185                     value = np.tile(value, (len(existing_piece.columns), 1)).T
#    4186
# -> 4187         self._set_item_mgr(key, value)
#    4188
#    4189     def _set_value(
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _set_item_mgr(self, key, value)
#    4144             self._mgr.insert(len(self._info_axis), key, value)
#    4145         else:
# -> 4146             self._iset_item_mgr(loc, value)
#    4147
#    4148         # check if we are modifying a copy
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _iset_item_mgr(self, loc, value, inplace)
#    4134     ) -> None:
#    4135         # when called from _set_item_mgr loc can be anything returned from get_loc
# -> 4136         self._mgr.iset(loc, value, inplace=inplace)
#    4137         self._clear_item_cache()
#    4138
#
# KeyboardInterrupt:

# %%
track_all = track.copy()
track_all['chrom'] = track_all['chr']
track_all['start'] = track_all['coord']-100
track_all['end'] = track_all['coord']+100

for p in [0, 1]:
    clr = phase_clrs[p]
    exp0 =  pd.read_csv(exps[p], sep='\t')
    
    pup = coolpup.pileup(clr, track_all, features_format='bed', local=True, view_df=hg38_arms,
                                        flank=200_000, expected_df = exp0, min_diag=0, nproc=8)
    fg = plotpup.plot(pup,
                             score=False, cmap='coolwarm', scale='log', sym=True,
                             height=5, vmax=1.5)

    fg.savefig(os.path.join(savedir, f"{track_base}_p{p+1}_allTF.svg"))

# %%
# 100 kb 

for quant in [2]:
    track_sub = track[track['quant']==quant]
    track_sub['chrom'] = track_sub['chr']
    track_sub['start'] = track_sub['coord']-100
    track_sub['end'] = track_sub['coord']+100
    
    for p in [0, 1]:
        clr = phase_clrs[p]
        exp0 =  pd.read_csv(exps[p], sep='\t')
    
        pup = coolpup.pileup(clr, track_sub, features_format='bed', local=True, view_df=hg38_arms,
                                        flank=200_000, expected_df = exp0, min_diag=0, nproc=8)
        fg = plotpup.plot(pup,
                             score=False, cmap='coolwarm', scale='log', sym=True,
                             height=5, vmax=1.7)

        fg
        #fg.savefig(os.path.join(savedir, f"{track_base}_p{p+1}.svg"))
# Out:
# INFO:coolpuppy:('chr5_p', 'chr5_p'): 2
# INFO:coolpuppy:('chr8_p', 'chr8_p'): 3
# INFO:coolpuppy:('chr7_p', 'chr7_p'): 3
# INFO:coolpuppy:('chr6_p', 'chr6_p'): 7
# INFO:coolpuppy:('chr2_p', 'chr2_p'): 6
# INFO:coolpuppy:('chr3_p', 'chr3_p'): 7
# INFO:coolpuppy:('chr1_p', 'chr1_p'): 17
# INFO:coolpuppy:('chr8_q', 'chr8_q'): 8
# INFO:coolpuppy:('chr4_q', 'chr4_q'): 8
# INFO:coolpuppy:('chr7_q', 'chr7_q'): 10
# INFO:coolpuppy:('chr9_p', 'chr9_p'): 6
# INFO:coolpuppy:('chr5_q', 'chr5_q'): 10
# INFO:coolpuppy:('chr6_q', 'chr6_q'): 9
# INFO:coolpuppy:('chr10_p', 'chr10_p'): 4
# INFO:coolpuppy:('chr11_p', 'chr11_p'): 1
# INFO:coolpuppy:('chr12_p', 'chr12_p'): 1
# INFO:coolpuppy:('chr3_q', 'chr3_q'): 11
# INFO:coolpuppy:('chr9_q', 'chr9_q'): 5
# INFO:coolpuppy:('chr13_q', 'chr13_q'): 6
# INFO:coolpuppy:('chr10_q', 'chr10_q'): 8
# INFO:coolpuppy:('chr11_q', 'chr11_q'): 8
# INFO:coolpuppy:('chr1_q', 'chr1_q'): 14
# INFO:coolpuppy:('chr2_q', 'chr2_q'): 13
# INFO:coolpuppy:('chr14_q', 'chr14_q'): 10
# INFO:coolpuppy:('chr18_p', 'chr18_p'): 3
# INFO:coolpuppy:('chr17_p', 'chr17_p'): 2
# INFO:coolpuppy:('chr16_p', 'chr16_p'): 2
# INFO:coolpuppy:('chr12_q', 'chr12_q'): 9
# INFO:coolpuppy:('chr15_q', 'chr15_q'): 4
# INFO:coolpuppy:('chr19_p', 'chr19_p'): 3
# INFO:coolpuppy:('chr20_p', 'chr20_p'): 1
# INFO:coolpuppy:('chr21_q', 'chr21_q'): 6
# INFO:coolpuppy:('chr19_q', 'chr19_q'): 3
# INFO:coolpuppy:('chr16_q', 'chr16_q'): 8
# INFO:coolpuppy:('chr22_q', 'chr22_q'): 8
# INFO:coolpuppy:('chr20_q', 'chr20_q'): 2
# INFO:coolpuppy:('chr18_q', 'chr18_q'): 10
# INFO:coolpuppy:('chr17_q', 'chr17_q'): 11
# INFO:coolpuppy:('chrX_p', 'chrX_p'): 2
# INFO:coolpuppy:('chrX_q', 'chrX_q'): 2
# INFO:coolpuppy:Total number of piled up windows: 253
# INFO:coolpuppy:('chr5_p', 'chr5_p'): 2
# INFO:coolpuppy:('chr8_p', 'chr8_p'): 3
# INFO:coolpuppy:('chr7_p', 'chr7_p'): 3
# INFO:coolpuppy:('chr6_p', 'chr6_p'): 7
# INFO:coolpuppy:('chr2_p', 'chr2_p'): 6
# INFO:coolpuppy:('chr3_p', 'chr3_p'): 7
# INFO:coolpuppy:('chr1_p', 'chr1_p'): 17
# INFO:coolpuppy:('chr8_q', 'chr8_q'): 8
# INFO:coolpuppy:('chr4_q', 'chr4_q'): 8
# INFO:coolpuppy:('chr7_q', 'chr7_q'): 10
# INFO:coolpuppy:('chr5_q', 'chr5_q'): 10
# INFO:coolpuppy:('chr9_p', 'chr9_p'): 6
# INFO:coolpuppy:('chr10_p', 'chr10_p'): 4
# INFO:coolpuppy:('chr6_q', 'chr6_q'): 9
# INFO:coolpuppy:('chr11_p', 'chr11_p'): 1
# INFO:coolpuppy:('chr12_p', 'chr12_p'): 1
# INFO:coolpuppy:('chr3_q', 'chr3_q'): 11
# INFO:coolpuppy:('chr9_q', 'chr9_q'): 5
# INFO:coolpuppy:('chr13_q', 'chr13_q'): 6
# INFO:coolpuppy:('chr10_q', 'chr10_q'): 8
# INFO:coolpuppy:('chr2_q', 'chr2_q'): 13
# INFO:coolpuppy:('chr11_q', 'chr11_q'): 8
# INFO:coolpuppy:('chr1_q', 'chr1_q'): 14
# INFO:coolpuppy:('chr18_p', 'chr18_p'): 3
# INFO:coolpuppy:('chr17_p', 'chr17_p'): 2
# INFO:coolpuppy:('chr16_p', 'chr16_p'): 2
# INFO:coolpuppy:('chr14_q', 'chr14_q'): 10
# INFO:coolpuppy:('chr12_q', 'chr12_q'): 9
# INFO:coolpuppy:('chr19_p', 'chr19_p'): 3
# INFO:coolpuppy:('chr20_p', 'chr20_p'): 1
# INFO:coolpuppy:('chr21_q', 'chr21_q'): 6
# INFO:coolpuppy:('chr15_q', 'chr15_q'): 4
# INFO:coolpuppy:('chr19_q', 'chr19_q'): 3
# INFO:coolpuppy:('chr16_q', 'chr16_q'): 8
# INFO:coolpuppy:('chr22_q', 'chr22_q'): 8
# INFO:coolpuppy:('chr20_q', 'chr20_q'): 2
# INFO:coolpuppy:('chr18_q', 'chr18_q'): 10
# INFO:coolpuppy:('chr17_q', 'chr17_q'): 11
# INFO:coolpuppy:('chrX_p', 'chrX_p'): 2
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-40:
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-36:
# Traceback (most recent call last):
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/connection.py", line 221, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Process ForkPoolWorker-35:
# Traceback (most recent call last):
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/varshini/anaconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/varshini/anaconda3/lib/python3.9/site-packages/coolpuppy/coolpup.py", line 1342, in pileup_region
#     final = self.accumulate_stream(
#   File "/home/varshini/anaconda3/lib/python3.9/site-packages/coolpuppy/coolpup.py", line 1256, in accumulate_stream
#     for snip in collapse(snip_stream, base_type=dict):
#   File "/home/varshini/anaconda3/lib/python3.9/site-packages/more_itertools/more.py", line 1262, in collapse
#     for node in nodes:
#   File "/home/varshini/anaconda3/lib/python3.9/site-packages/coolpuppy/coolpup.py", line 1076, in _stream_snips
#     bigdata = self.get_data(region1=region1, region2=region2)
#   File "/home/varshini/anaconda3/lib/python3.9/site-packages/coolpuppy/coolpup.py", line 1048, in get_data
#     data = self.clr.matrix(sparse=True, balance=self.clr_weight_name).fetch(
#   File "/home/varshini/anaconda3/lib/python3.9/site-packages/cooler/core/_selectors.py", line 150, in fetch
#     return self._slice(self.field, i0, i1, j0, j1)
#   File "/home/varshini/anaconda3/lib/python3.9/site-packages/cooler/api.py", line 370, in _slice
#     return matrix(
#   File "/home/varshini/anaconda3/lib/python3.9/site-packages/cooler/api.py", line 742, in matrix
#     mat = engine.to_sparse_matrix()
#   File "/home/varshini/anaconda3/lib/python3.9/site-packages/cooler/core/_rangequery.py", line 296, in to_sparse_matrix
#     return spmatrix_slice_from_dict(self.get(), *self.bbox, self.field)
#   File "/home/varshini/anaconda3/lib/python3.9/site-packages/cooler/core/_rangequery.py", line 275, in get
#     dct = concat(*self.__iter__())
#   File "/home/varshini/anaconda3/lib/python3.9/site-packages/cooler/core/_rangequery.py", line 268, in __iter__
#     yield task[0](*task[1:])
#   File "/home/varshini/anaconda3/lib/python3.9/site-packages/cooler/core/_rangequery.py", line 202, in __call__
#     bin2_extracted = bin2_selector[slc]
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "/home/varshini/anaconda3/lib/python3.9/site-packages/h5py/_hl/dataset.py", line 741, in __getitem__
#     return self._fast_reader.read(args)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/coolpuppy/coolpup.py in pileupsWithControl(self, nproc, groupby, ignore_group_order, modify_2Dintervals_func, postprocess_func, extra_sum_funcs)
#    1479             with Pool(nproc) as p:
# -> 1480                 pileups = list(p.starmap(f, zip(regions1, regions2)))
#    1481             uninstall_mp_handler()
#
# ~/anaconda3/lib/python3.9/multiprocessing/pool.py in starmap(self, func, iterable, chunksize)
#     371         '''
# --> 372         return self._map_async(func, iterable, starmapstar, chunksize).get()
#     373
#
# ~/anaconda3/lib/python3.9/multiprocessing/pool.py in get(self, timeout)
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#
# ~/anaconda3/lib/python3.9/multiprocessing/pool.py in wait(self, timeout)
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#
# ~/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     580             if not signaled:
# --> 581                 signaled = self._cond.wait(timeout)
#     582             return signaled
#
# ~/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2562392/3634227629.py in <module>
#      11         exp0 =  pd.read_csv(exps[p], sep='\t')
#      12
# ---> 13         pup = coolpup.pileup(clr, track_sub, features_format='bed', local=True, view_df=hg38_arms,
#      14                                         flank=200_000, expected_df = exp0, min_diag=0, nproc=8)
#      15         fg = plotpup.plot(pup,
#
# ~/anaconda3/lib/python3.9/site-packages/coolpuppy/coolpup.py in pileup(clr, features, features_format, view_df, expected_df, expected_value_col, clr_weight_name, flank, minshift, maxshift, nshifts, ooe, mindist, maxdist, min_diag, subset, by_window, by_strand, by_distance, groupby, ignore_group_order, flip_negative_strand, local, coverage_norm, trans, rescale, rescale_flank, rescale_size, store_stripes, nproc, seed)
#    2217         pups["by_distance"] = True
#    2218     else:
# -> 2219         pups = PU.pileupsWithControl(groupby=groupby, ignore_group_order=ignore_group_order,)
#    2220         pups["by_window"] = False
#    2221         pups["by_strand"] = False
#
# ~/anaconda3/lib/python3.9/site-packages/coolpuppy/coolpup.py in pileupsWithControl(self, nproc, groupby, ignore_group_order, modify_2Dintervals_func, postprocess_func, extra_sum_funcs)
#    1478             install_mp_handler()
#    1479             with Pool(nproc) as p:
# -> 1480                 pileups = list(p.starmap(f, zip(regions1, regions2)))
#    1481             uninstall_mp_handler()
#    1482         else:
#
# ~/anaconda3/lib/python3.9/multiprocessing/pool.py in __exit__(self, exc_type, exc_val, exc_tb)
#     734
#     735     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 736         self.terminate()
#     737
#     738 #
#
# ~/anaconda3/lib/python3.9/multiprocessing/pool.py in terminate(self)
#     652         util.debug('terminating pool')
#     653         self._state = TERMINATE
# --> 654         self._terminate()
#     655
#     656     def join(self):
#
# ~/anaconda3/lib/python3.9/multiprocessing/util.py in __call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     222                 sub_debug('finalizer calling %s with args %s and kwargs %s',
#     223                           self._callback, self._args, self._kwargs)
# --> 224                 res = self._callback(*self._args, **self._kwargs)
#     225             self._weakref = self._callback = self._args = \
#     226                             self._kwargs = self._key = None
#
# ~/anaconda3/lib/python3.9/multiprocessing/pool.py in _terminate_pool(cls, taskqueue, inqueue, outqueue, pool, change_notifier, worker_handler, task_handler, result_handler, cache)
#     690
#     691         util.debug('helping task handler/workers to finish')
# --> 692         cls._help_stuff_finish(inqueue, task_handler, len(pool))
#     693
#     694         if (not result_handler.is_alive()) and (len(cache) != 0):
#
# ~/anaconda3/lib/python3.9/multiprocessing/pool.py in _help_stuff_finish(inqueue, task_handler, size)
#     670         # task_handler may be blocked trying to put items on inqueue
#     671         util.debug('removing tasks from inqueue until task handler finished')
# --> 672         inqueue._rlock.acquire()
#     673         while task_handler.is_alive() and inqueue._reader.poll():
#     674             inqueue._reader.recv()
#
# KeyboardInterrupt:

# %%
# now explode on loops and pileup on CTCF-CTCF loops vs. exclusive ?? E-P loops?

# %%
loop_basedir = '/mnt/md0/varshini/Analysis/Blood/complete_analyses/loops_anchors'
lc = 'merged_calls_125kb_q0.01_classes_new.txt'
excl = 'merged_calls_125kb_q0.01_classes_excl.txt'
ls = 'nfe2_oe_scores_2000bp.tsv'

loop_classes = pd.read_csv(os.path.join(loop_basedir, lc), sep='\t').rename({'seqnames1':'chrom1','seqnames2':'chr2', 'pair':'class'}, axis=1)
loop_classes['coord1']=loop_classes[['start1','end1']].mean(axis=1)
loop_classes['coord2']=loop_classes[['start2','end2']].mean(axis=1)


excl_loop_classes = pd.read_csv(os.path.join(loop_basedir, excl), sep='\t').rename({'seqnames1':'chrom1','seqnames2':'chr2', 'pair':'class'}, axis=1).drop('NA.',axis=1)
excl_loop_classes['coord1']=excl_loop_classes[['start1','end1']].mean(axis=1)
excl_loop_classes['coord2']=excl_loop_classes[['start2','end2']].mean(axis=1)


loops_oe = pd.read_csv(os.path.join(loop_basedir, ls), sep='\t', names=['chr1','start1','end1','chr2','start2','end2','aavs1','nfe2'])

loop_class_strengths = loops_oe.merge(loop_classes, how='inner', on=['start1','end1','chr2','start2','end2'])
loop_class_strengths_excl = loops_oe.merge(excl_loop_classes, how='inner', on=['start1','end1','chr2','start2','end2'])

# %%
track_test = pd.read_csv("/mnt/md0/varshini/Analysis/Blood/complete_analyses/matchmakers/matchmaker_scores/AAVS1_P3_tf_acrs_sorted_enhancernotpromoternotctcf_loopscores_100000_withpeaks.tsv", sep='\t', index_col=0)

# %%
exploded.columns
# Out:
# Index(['chrom1', 'coord', 'perturbation_name', 'triangle_score_P1',
#        'crosser_loop_scores_P1', 'crosser_loop_classes_P1',
#        'crosser_loop_coords_P1', 'ss_loop_scores_P1', 'ss_loop_classes_P1',
#        'ss_loop_coords_P1', 'agg_crosser_score_P1', 'agg_ss_score_P1',
#        'mean_crosser_score_P1', 'mean_ss_score_P1', 'triangle_score_P2',
#        'crosser_loop_scores_P2', 'crosser_loop_classes_P2',
#        'crosser_loop_coords_P2', 'ss_loop_scores_P2', 'ss_loop_classes_P2',
#        'ss_loop_coords_P2', 'agg_crosser_score_P2', 'agg_ss_score_P2',
#        'mean_crosser_score_P2', 'mean_ss_score_P2', 'quant', 'start1', 'end1',
#        'start2', 'end2', 'chrom2', 'coord1', 'coord2', 'distance'],
#       dtype='object')

# %%
track_test[(track_test['chr']=='chr10')&(track_test['coord']==124649029.0)][['chr','coord','ss_loop_coords','ss_loop_scores','crosser_loop_scores', 'crosser_loop_classes']]
# Out:
#         chr        coord                                     ss_loop_coords  \
# 5001  chr10  124649029.0  [(124676500.5, 124741500.5), (124678500.5, 124...
#
#                                          ss_loop_scores  \
# 5001  [3.1692181275883, 2.5870752865836595, 2.338795...
#
#                                     crosser_loop_scores  \
# 5001  [3.2707450355886563, 5.060593540514564, 2.8760...
#
#                      crosser_loop_classes
# 5001  ['E-P', 'E-P', 'E-E', 'E-P', 'E-E']

# %%
t['crosser_loop_scores']
# Out:
# 4397    [2.489755552243041, 2.5576621210896757, 3.3673...
# Name: crosser_loop_scores, dtype: object

# %%
loop_class_strengths[(loop_class_strengths['chr1']=='chr9') & (loop_class_strengths['coord1'] == 69672500.5)]
# Out:
#        chr1    start1      end1  chr2    start2      end2     aavs1      nfe2  \
# 60055  chr9  69670001  69675000  chr9  69757001  69762000  2.761549  2.138302
#
#       chrom1 annotation1 annotation2 class      coord1      coord2
# 60055   chr9           P           P   P-P  69672500.5  69759500.5

# %%
exploded
# Out:
#     chrom1        coord perturbation_name  triangle_score_P1  \
# 0     chr1    6317423.0              NFE2           1.424136
# 0     chr1    6317423.0              NFE2           1.424136
# 0     chr1    6317423.0              NFE2           1.424136
# 0     chr1    6317423.0              NFE2           1.424136
# 0     chr1    6317423.0              NFE2           1.424136
# ..     ...          ...               ...                ...
# 869   chrX   53374574.5              NFE2           1.912914
# 872   chrX  119427490.0              NFE2           1.074473
# 872   chrX  119427490.0              NFE2           1.074473
# 874   chrX  125399069.5              NFE2           1.486328
# 874   chrX  125399069.5              NFE2           1.486328
#
#     crosser_loop_scores_P1              crosser_loop_classes_P1  \
# 0                 2.408679   [P-P, P-CTCF, P-CTCF, P-P, P-CTCF]
# 0                 2.634773   [P-P, P-CTCF, P-CTCF, P-P, P-CTCF]
# 0                 6.097739   [P-P, P-CTCF, P-CTCF, P-P, P-CTCF]
# 0                 2.961282   [P-P, P-CTCF, P-CTCF, P-P, P-CTCF]
# 0                  4.88619   [P-P, P-CTCF, P-CTCF, P-P, P-CTCF]
# ..                     ...                                  ...
# 869               6.104667  [E-Null, CTCF-CTCF, P-CTCF, P-CTCF]
# 872               1.910014                     [P-P, CTCF-Null]
# 872               2.006176                     [P-P, CTCF-Null]
# 874               2.016216                  [E-Null, Null-Null]
# 874               2.356929                  [E-Null, Null-Null]
#
#                                 crosser_loop_coords_P1  \
# 0    [(6236500.5, 6393500.5), (6238500.5, 6343500.5...
# 0    [(6236500.5, 6393500.5), (6238500.5, 6343500.5...
# 0    [(6236500.5, 6393500.5), (6238500.5, 6343500.5...
# 0    [(6236500.5, 6393500.5), (6238500.5, 6343500.5...
# 0    [(6236500.5, 6393500.5), (6238500.5, 6343500.5...
# ..                                                 ...
# 869  [(53289000.5, 53441000.5), (53315500.5, 534455...
# 872  [(119399500.5, 119468500.5), (119417500.5, 119...
# 872  [(119399500.5, 119468500.5), (119417500.5, 119...
# 874  [(125337500.5, 125402500.5), (125379000.5, 125...
# 874  [(125337500.5, 125402500.5), (125379000.5, 125...
#
#                                      ss_loop_scores_P1  \
# 0    [1.355843235772496, 5.671889825626111, 2.71241...
# 0    [1.355843235772496, 5.671889825626111, 2.71241...
# 0    [1.355843235772496, 5.671889825626111, 2.71241...
# 0    [1.355843235772496, 5.671889825626111, 2.71241...
# 0    [1.355843235772496, 5.671889825626111, 2.71241...
# ..                                                 ...
# 869                                             [None]
# 872  [1.2557127056371773, 2.1099793952016794, 1.920...
# 872  [1.2557127056371773, 2.1099793952016794, 1.920...
# 874                                                 []
# 874                                                 []
#
#                                     ss_loop_classes_P1  \
# 0    [Null-Null, CTCF-CTCF, P-CTCF, P-P, P-CTCF, P-...
# 0    [Null-Null, CTCF-CTCF, P-CTCF, P-P, P-CTCF, P-...
# 0    [Null-Null, CTCF-CTCF, P-CTCF, P-P, P-CTCF, P-...
# 0    [Null-Null, CTCF-CTCF, P-CTCF, P-P, P-CTCF, P-...
# 0    [Null-Null, CTCF-CTCF, P-CTCF, P-P, P-CTCF, P-...
# ..                                                 ...
# 869                                              [P-P]
# 872                           [E-P, P-CTCF, CTCF-Null]
# 872                           [E-P, P-CTCF, CTCF-Null]
# 874                                                 []
# 874                                                 []
#
#                                      ss_loop_coords_P1  ...  mean_ss_score_P2  \
# 0    [(6249500.5, 6280500.5), (6347500.5, 6404500.5...  ...          3.296496
# 0    [(6249500.5, 6280500.5), (6347500.5, 6404500.5...  ...          3.296496
# 0    [(6249500.5, 6280500.5), (6347500.5, 6404500.5...  ...          3.296496
# 0    [(6249500.5, 6280500.5), (6347500.5, 6404500.5...  ...          3.296496
# 0    [(6249500.5, 6280500.5), (6347500.5, 6404500.5...  ...          3.296496
# ..                                                 ...  ...               ...
# 869                         [(53424500.5, 53433500.5)]  ...               NaN
# 872  [(119469500.5, 119482500.5), (119470500.5, 119...  ...          1.731594
# 872  [(119469500.5, 119482500.5), (119470500.5, 119...  ...          1.731594
# 874                                                 []  ...               NaN
# 874                                                 []  ...               NaN
#
#      quant     start1       end1     start2       end2 chrom2       coord1  \
# 0        2    6236400    6236600    6393400    6393600   chr1    6236500.5
# 0        2    6238400    6238600    6343400    6343600   chr1    6238500.5
# 0        2    6247400    6247600    6343400    6343600   chr1    6247500.5
# 0        2    6247400    6247600    6395400    6395600   chr1    6247500.5
# 0        2    6247400    6247600    6404400    6404600   chr1    6247500.5
# ..     ...        ...        ...        ...        ...    ...          ...
# 869      3   53316400   53316600   53436400   53436600   chrX   53316500.5
# 872      1  119399400  119399600  119468400  119468600   chrX  119399500.5
# 872      1  119417400  119417600  119512400  119512600   chrX  119417500.5
# 874      2  125337400  125337600  125402400  125402600   chrX  125337500.5
# 874      2  125378900  125379100  125434900  125435100   chrX  125379000.5
#
#           coord2  distance
# 0      6393500.5  157000.0
# 0      6343500.5  105000.0
# 0      6343500.5   96000.0
# 0      6395500.5  148000.0
# 0      6404500.5  157000.0
# ..           ...       ...
# 869   53436500.5  120000.0
# 872  119468500.5   69000.0
# 872  119512500.5   95000.0
# 874  125402500.5   65000.0
# 874  125435000.5   56000.0
#
# [1415 rows x 34 columns]

# %%
track
# Out:
#       chr        coord perturbation_name  triangle_score_P1  \
# 0    chr1    6317423.0              NFE2           1.424136
# 1    chr1    9275701.5              NFE2           0.903714
# 2    chr1   10415493.5              NFE2           1.252600
# 3    chr1   10459322.5              NFE2           1.254360
# 4    chr1   12496644.5              NFE2           1.371587
# ..    ...          ...               ...                ...
# 870  chrX   55003094.0              NFE2           0.985873
# 871  chrX   72532503.0              NFE2           0.944656
# 872  chrX  119427490.0              NFE2           1.074473
# 873  chrX  124698899.0              NFE2           1.305031
# 874  chrX  125399069.5              NFE2           1.486328
#
#                                 crosser_loop_scores_P1  \
# 0    [2.4086793870982293, 2.6347728680930915, 6.097...
# 1                                                   []
# 2    [5.847955839597662, 3.9857051860777433, 1.8559...
# 3    [3.9857051860777433, 1.5249911495733304, 5.391...
# 4                                                   []
# ..                                                 ...
# 870                                                 []
# 871                                                 []
# 872           [1.9100143939863061, 2.0061763914965294]
# 873                                                 []
# 874           [2.0162160940703817, 2.3569293225764754]
#
#                 crosser_loop_classes_P1  \
# 0    [P-P, P-CTCF, P-CTCF, P-P, P-CTCF]
# 1                                    []
# 2            [P-CTCF, E-CTCF, P-P, P-P]
# 3               [E-CTCF, P-P, E-P, P-P]
# 4                                    []
# ..                                  ...
# 870                                  []
# 871                                  []
# 872                    [P-P, CTCF-Null]
# 873                                  []
# 874                 [E-Null, Null-Null]
#
#                                 crosser_loop_coords_P1  \
# 0    [(6236500.5, 6393500.5), (6238500.5, 6343500.5...
# 1                                                   []
# 2    [(10377500.5, 10427500.5), (10377500.5, 104945...
# 3    [(10377500.5, 10494500.5), (10399500.5, 104735...
# 4                                                   []
# ..                                                 ...
# 870                                                 []
# 871                                                 []
# 872  [(119399500.5, 119468500.5), (119417500.5, 119...
# 873                                                 []
# 874  [(125337500.5, 125402500.5), (125379000.5, 125...
#
#                                      ss_loop_scores_P1  \
# 0    [1.355843235772496, 5.671889825626111, 2.71241...
# 1                                                   []
# 2    [1.3521768641424066, None, None, 5.39117361182...
# 3    [5.847955839597662, 1.3521768641424066, 1.9960...
# 4                                 [1.7295859450227642]
# ..                                                 ...
# 870                               [2.2985223327865496]
# 871                                                 []
# 872  [1.2557127056371773, 2.1099793952016794, 1.920...
# 873                                                 []
# 874                                                 []
#
#                                     ss_loop_classes_P1  \
# 0    [Null-Null, CTCF-CTCF, P-CTCF, P-P, P-CTCF, P-...
# 1                                                   []
# 2         [P-CTCF, P-Null, E-Null, E-P, P-P, E-P, E-P]
# 3    [P-CTCF, P-CTCF, E-CTCF, P-Null, P-P, E-P, E-N...
# 4                                                [E-E]
# ..                                                 ...
# 870                                              [E-P]
# 871                                                 []
# 872                           [E-P, P-CTCF, CTCF-Null]
# 873                                                 []
# 874                                                 []
#
#                                      ss_loop_coords_P1  ...  \
# 0    [(6249500.5, 6280500.5), (6347500.5, 6404500.5...  ...
# 1                                                   []  ...
# 2    [(10378500.5, 10398500.5), (10388500.5, 103985...  ...
# 3    [(10377500.5, 10427500.5), (10378500.5, 103985...  ...
# 4                           [(12449500.5, 12477500.5)]  ...
# ..                                                 ...  ...
# 870                         [(55016500.5, 55027500.5)]  ...
# 871                                                 []  ...
# 872  [(119469500.5, 119482500.5), (119470500.5, 119...  ...
# 873                                                 []  ...
# 874                                                 []  ...
#
#                                      ss_loop_scores_P2  \
# 0    [1.2319300257801211, 6.0696025408026415, 2.741...
# 1                                                   []
# 2    [1.1131026977927398, None, None, 4.71366338352...
# 3    [4.798552385315165, 1.1131026977927398, 1.8237...
# 4                                 [1.7838422904805538]
# ..                                                 ...
# 870                               [2.5600234176815446]
# 871                                                 []
# 872  [1.2915327099944827, 2.2748984032899036, 1.628...
# 873                                                 []
# 874                                                 []
#
#                                     ss_loop_classes_P2  \
# 0    [Null-Null, CTCF-CTCF, P-CTCF, P-P, P-CTCF, P-...
# 1                                                   []
# 2         [P-CTCF, P-Null, E-Null, E-P, P-P, E-P, E-P]
# 3    [P-CTCF, P-CTCF, E-CTCF, P-Null, P-P, E-P, E-N...
# 4                                                [E-E]
# ..                                                 ...
# 870                                              [E-P]
# 871                                                 []
# 872                           [E-P, P-CTCF, CTCF-Null]
# 873                                                 []
# 874                                                 []
#
#                                      ss_loop_coords_P2  agg_crosser_score_P2  \
# 0    [(6249500.5, 6280500.5), (6347500.5, 6404500.5...             19.120310
# 1                                                   []              0.000000
# 2    [(10378500.5, 10398500.5), (10388500.5, 103985...             10.888428
# 3    [(10377500.5, 10427500.5), (10378500.5, 103985...             10.890766
# 4                           [(12449500.5, 12477500.5)]              0.000000
# ..                                                 ...                   ...
# 870                         [(55016500.5, 55027500.5)]              0.000000
# 871                                                 []              0.000000
# 872  [(119469500.5, 119482500.5), (119470500.5, 119...              3.150616
# 873                                                 []              0.000000
# 874                                                 []              4.337231
#
#      agg_ss_score_P2 mean_crosser_score_P2 mean_ss_score_P2 quant chr_diff  \
# 0          19.778978              3.824062         3.296496     2     chr1
# 1           0.000000                   NaN              NaN     0     chr1
# 2                NaN              2.722107         1.980003     1     chr1
# 3                NaN              2.722692         1.980977     1     chr1
# 4           1.783842                   NaN         1.783842     2     chr1
# ..               ...                   ...              ...   ...      ...
# 870         2.560023                   NaN         2.560023     1     chrX
# 871         0.000000                   NaN              NaN     0     chrX
# 872         5.194783              1.575308         1.731594     1     chrX
# 873         0.000000                   NaN              NaN     2     chrX
# 874         0.000000              2.168615              NaN     2     chrX
#
#     quant_diff
# 0          2.0
# 1          0.0
# 2          1.0
# 3          1.0
# 4          2.0
# ..         ...
# 870        1.0
# 871        1.0
# 872        1.0
# 873        1.0
# 874        2.0
#
# [875 rows x 28 columns]

# %%
exploded[(exploded['chrom1']=='chr9') & (exploded['coord1']==69672500.5)][['chrom1','coord','ss_loop_coords_P2','crosser_loop_classes_P1','crosser_loop_scores_P1']]
# Out:
#     chrom1       coord ss_loop_coords_P2 crosser_loop_classes_P1  \
# 828   chr9  69719630.5                []                   [P-P]
#
#     crosser_loop_scores_P1
# 828               2.761549

# %%
exploded[exploded['chrom1']=='chr9'].sort_values(by=['chrom1','crosser_loop_coords_P2'])[['chrom1','coord1','coord2', 'crosser_loop_scores_P1','crosser_loop_scores_P2']]
# Out:
#     chrom1       coord1       coord2 crosser_loop_scores_P1  \
# 815   chr9     215500.5     273500.5               3.103723
# 815   chr9     215500.5     281500.5               2.808037
# 815   chr9     215500.5     296500.5               3.489488
# 815   chr9     215500.5     306500.5               3.505513
# 816   chr9    5441500.5    5589500.5               5.434248
# ..     ...          ...          ...                    ...
# 850   chr9  133113500.5  133145500.5               2.262269
# 850   chr9  133121500.5  133147500.5               2.038141
# 852   chr9  135907500.5  135961500.5               3.001933
# 852   chr9  135909500.5  135950500.5               2.644549
# 853   chr9  136090500.5  136122500.5                3.11675
#
#     crosser_loop_scores_P2
# 815               2.667301
# 815               2.828475
# 815               3.640506
# 815               4.993697
# 816               3.543355
# ..                     ...
# 850               2.253316
# 850               1.869802
# 852               3.028057
# 852               2.692541
# 853               3.138936
#
# [71 rows x 5 columns]

# %%
exploded = track.explode(['crosser_loop_scores_P2','crosser_loop_scores_P1', 'crosser_loop_coords_P2', 'crosser_loop_classes_P2']).dropna(subset='crosser_loop_coords_P2')

exploded['start1'] = exploded['crosser_loop_coords_P2'].apply(lambda x: int(np.floor(x[0]-100)))
exploded['end1'] = exploded['crosser_loop_coords_P2'].apply(lambda x: int(np.floor(x[0]+100)))
exploded['start2'] = exploded['crosser_loop_coords_P2'].apply(lambda x: int(np.floor(x[1]-100)))
exploded['end2'] = exploded['crosser_loop_coords_P2'].apply(lambda x: int(np.floor(x[1]+100)))
exploded['chrom2'] = exploded['chr']
exploded['coord1'] = exploded['crosser_loop_coords_P2'].apply(lambda x: x[0])
exploded['coord2'] = exploded['crosser_loop_coords_P2'].apply(lambda x: x[1])
exploded['distance'] = exploded['coord2'] - exploded['coord1']
exploded.rename({'chr':'chrom1'}, inplace=True, axis=1)

# %%
exploded[['crosser_loop_coords_P1','crosser_loop_coords_P2']]
# Out:
#                                 crosser_loop_coords_P1  \
# 0    [(6236500.5, 6393500.5), (6238500.5, 6343500.5...
# 0    [(6236500.5, 6393500.5), (6238500.5, 6343500.5...
# 0    [(6236500.5, 6393500.5), (6238500.5, 6343500.5...
# 0    [(6236500.5, 6393500.5), (6238500.5, 6343500.5...
# 0    [(6236500.5, 6393500.5), (6238500.5, 6343500.5...
# ..                                                 ...
# 869  [(53289000.5, 53441000.5), (53315500.5, 534455...
# 872  [(119399500.5, 119468500.5), (119417500.5, 119...
# 872  [(119399500.5, 119468500.5), (119417500.5, 119...
# 874  [(125337500.5, 125402500.5), (125379000.5, 125...
# 874  [(125337500.5, 125402500.5), (125379000.5, 125...
#
#          crosser_loop_coords_P2
# 0        (6236500.5, 6393500.5)
# 0        (6238500.5, 6343500.5)
# 0        (6247500.5, 6343500.5)
# 0        (6247500.5, 6395500.5)
# 0        (6247500.5, 6404500.5)
# ..                          ...
# 869    (53316500.5, 53436500.5)
# 872  (119399500.5, 119468500.5)
# 872  (119417500.5, 119512500.5)
# 874  (125337500.5, 125402500.5)
# 874  (125379000.5, 125435000.5)
#
# [1415 rows x 2 columns]

# %%
exploded_merged = pd.merge(exploded,loop_class_strengths_excl,on=['chrom1','coord1','coord2'],
                           how="inner", suffixes=('','_lc'))

# %%
exploded_merged.columns
# Out:
# Index(['chrom1', 'coord', 'perturbation_name', 'triangle_score_P1',
#        'crosser_loop_scores_P1', 'crosser_loop_classes_P1',
#        'crosser_loop_coords_P1', 'ss_loop_scores_P1', 'ss_loop_classes_P1',
#        'ss_loop_coords_P1', 'agg_crosser_score_P1', 'agg_ss_score_P1',
#        'mean_crosser_score_P1', 'mean_ss_score_P1', 'triangle_score_P2',
#        'crosser_loop_scores_P2', 'crosser_loop_classes_P2',
#        'crosser_loop_coords_P2', 'ss_loop_scores_P2', 'ss_loop_classes_P2',
#        'ss_loop_coords_P2', 'agg_crosser_score_P2', 'agg_ss_score_P2',
#        'mean_crosser_score_P2', 'mean_ss_score_P2', 'quant', 'chr_diff',
#        'quant_diff', 'start1', 'end1', 'start2', 'end2', 'chrom2', 'coord1',
#        'coord2', 'distance', 'chr1', 'start1_lc', 'end1_lc', 'chr2',
#        'start2_lc', 'end2_lc', 'aavs1', 'nfe2', 'width1', 'strand1', 'width2',
#        'strand2', 'anchor1_annotation', 'anchor2_annotation', 'class'],
#       dtype='object')

# %%
exploded_merged.columns
# Out:
# Index(['chrom1', 'coord', 'perturbation_name', 'triangle_score_P1',
#        'crosser_loop_scores_P1', 'crosser_loop_classes_P1',
#        'crosser_loop_coords_P1', 'ss_loop_scores_P1', 'ss_loop_classes_P1',
#        'ss_loop_coords_P1', 'agg_crosser_score_P1', 'agg_ss_score_P1',
#        'mean_crosser_score_P1', 'mean_ss_score_P1', 'triangle_score_P2',
#        'crosser_loop_scores_P2', 'crosser_loop_classes_P2',
#        'crosser_loop_coords_P2', 'ss_loop_scores_P2', 'ss_loop_classes_P2',
#        'ss_loop_coords_P2', 'agg_crosser_score_P2', 'agg_ss_score_P2',
#        'mean_crosser_score_P2', 'mean_ss_score_P2', 'quant', 'chr_diff',
#        'quant_diff', 'start1', 'end1', 'start2', 'end2', 'chrom2', 'coord1',
#        'coord2', 'distance', 'chr1', 'start1_lc', 'end1_lc', 'chr2',
#        'start2_lc', 'end2_lc', 'aavs1', 'nfe2', 'width1', 'strand1', 'width2',
#        'strand2', 'anchor1_annotation', 'anchor2_annotation', 'class'],
#       dtype='object')

# %%
exploded_merged['loop_fc'] = exploded_merged['nfe2']/exploded_merged['aavs1']
exploded_merged['triangle_fc'] = exploded_merged['triangle_score_P2']/exploded_merged['triangle_score_P1']
exploded_merged = exploded_merged[(exploded_merged['quant']==2) | (exploded_merged['quant']==3)]

# %%
exploded_merged['diff'] = exploded_merged['start1'] -exploded_merged['start1_lc']

# %%
exploded_merged[['chrom1','start1_lc',
                 'diff','crosser_loop_scores_P2','nfe2']].iloc[100:115,:]
# Out:
#     chrom1  start1_lc  diff crosser_loop_scores_P2      nfe2
# 134   chr4  123400001  2399               1.559538  1.559538
# 135   chr4  139177001  2399               7.397482  7.397482
# 136   chr4  139401001  2399               2.151818  2.151818
# 137   chr4  139414001  2399               2.825326  2.825326
# 138   chr4  139414001  2399               3.716874  3.716874
# 140   chr4  176193001  2399               3.596181  3.596181
# 141   chr4  184340001  2399               3.607176  3.607176
# 142   chr4  184384001  2399               2.594687  2.594687
# 143   chr4  184415001  2399               3.441371  3.441371
# 144   chr5    6630001  2399                3.15403  3.154030
# 145   chr5    6630001  2399               4.501471  4.501471
# 148   chr5   39218001  2399                2.06055  2.060550
# 153   chr5   68294501  2399               2.817629  2.817629
# 154   chr5   68385001  2399               2.055988  2.055988
# 155   chr5   72135001  2399               4.791815  4.791815

# %%
plt.scatter(exploded_merged['crosser_loop_scores_P2'],exploded_merged['nfe2'], alpha=0.1)

# %%
exploded_merged['nfe2'].median()
# Out:
# 2.6832408262873115

# %%
sub = exploded_merged[exploded_merged['crosser_loop_scores_P2'] != exploded_merged['nfe2']]

# %%
plt.hist(exploded_merged['crosser_loop_scores_P2'].dropna(), alpha=0.5)
plt.hist(exploded_merged['nfe2'].dropna(),alpha=0.5)
# Out:
# (array([123., 111.,  45.,  22.,   7.,   4.,   5.,   1.,   1.,   2.]),
#  array([ 0.85901089,  2.34795188,  3.83689287,  5.32583386,  6.81477485,
#          8.30371585,  9.79265684, 11.28159783, 12.77053882, 14.25947981,
#         15.7484208 ]),
#  <BarContainer object of 10 artists>)

# %%
sub[['chrom1','coord1','start1','crosser_loop_scores_P2', 'nfe2']]
# Out:
#     chrom1       coord1     start1 crosser_loop_scores_P2       nfe2
# 0     chr1   15816500.5   15816400               2.827134   2.827134
# 8     chr1   37891500.5   37891400               1.556277   1.556277
# 15    chr1   65067500.5   65067400                   None        NaN
# 18    chr1   84668500.5   84668400               3.228325   3.228325
# 22    chr1   89804500.5   89804400              10.604682  10.604682
# ..     ...          ...        ...                    ...        ...
# 439  chr22   25565500.5   25565400                   None        NaN
# 440  chr22   25566500.5   25566400                   None        NaN
# 449  chr22   49931500.5   49931400               1.299063   1.299063
# 457   chrX   40013500.5   40013400                2.13493   2.134930
# 465   chrX  125337500.5  125337400               1.834305   1.834305
#
# [66 rows x 5 columns]

# %%
CTCF = ['E-CTCF','P-CTCF', 'CTCF-CTCF']
cc = exploded_merged[exploded_merged['crosser_loop_classes_P2'].isin(CTCF)]

# %%
cc['distance'] = cc['coord2'] - cc['coord1']

# %%
CRE = ['E-E','E-P','P-P']
cre = exploded_merged[exploded_merged['crosser_loop_classes_P2'].isin(CRE)]
plt.scatter(cre['loop_fc'], cre['triangle_fc'])

# %%
counts, bin_edges = np.histogram(cc['distance'], bins=10)
sns.histplot(cc['distance'], bins=10)
# Out:
# <AxesSubplot:xlabel='distance', ylabel='Count'>

# %%
exploded_excl = pd.merge(loop_class_strengths_excl,exploded,on=['chrom1','coord1','coord2'],
                           how="outer", suffixes=('','_lc'), indicator=True)
exploded_excl = exploded_excl[exploded_excl['_merge']=='left_only']
exploded_excl['distance'] = exploded_excl['start2'] - exploded_excl['start1']

# %%
exploded_excl['loop_fc'] = exploded_excl['nfe2']/exploded_excl['aavs1']

# %%
cc2 = exploded_excl[exploded_excl['class'].isin(CTCF)]
cre2 = exploded_excl[exploded_excl['class'].isin(CRE)]

# %%
cc2
# Out:
#        chr1       start1         end1  chr2       start2         end2  \
# 0      chr1     868501.0     873500.0  chr1     972501.0     977500.0
# 1      chr1     902501.0     907500.0  chr1     974501.0     979500.0
# 2      chr1     903001.0     908000.0  chr1     936001.0     941000.0
# 3      chr1     903001.0     908000.0  chr1     959001.0     964000.0
# 4      chr1     904001.0     909000.0  chr1     921001.0     926000.0
# ...     ...          ...          ...   ...          ...          ...
# 32300  chrX  154409001.0  154414000.0  chrX  154532001.0  154537000.0
# 32305  chrX  154470001.0  154475000.0  chrX  154533001.0  154538000.0
# 32310  chrX  154774001.0  154779000.0  chrX  154838001.0  154843000.0
# 32315  chrX  155090501.0  155095500.0  chrX  155818501.0  155823500.0
# 32316  chrX  155092001.0  155097000.0  chrX  155146001.0  155151000.0
#
#            aavs1       nfe2 chrom1  width1  ... chr_diff  quant_diff  \
# 0       1.979449   1.771716   chr1  5000.0  ...      NaN         NaN
# 1       3.361771   3.340515   chr1  5000.0  ...      NaN         NaN
# 2       2.114132   2.400818   chr1  5000.0  ...      NaN         NaN
# 3       2.093094   1.927533   chr1  5000.0  ...      NaN         NaN
# 4       1.266917   1.260933   chr1  5000.0  ...      NaN         NaN
# ...          ...        ...    ...     ...  ...      ...         ...
# 32300   6.983077   6.096496   chrX  5000.0  ...      NaN         NaN
# 32305   2.814773   2.331604   chrX  5000.0  ...      NaN         NaN
# 32310   2.629822   2.431024   chrX  5000.0  ...      NaN         NaN
# 32315  10.621848  12.699626   chrX  5000.0  ...      NaN         NaN
# 32316   2.377065   2.084237   chrX  5000.0  ...      NaN         NaN
#
#       start1_lc end1_lc start2_lc end2_lc  chrom2  distance     _merge  \
# 0           NaN     NaN       NaN     NaN     NaN  104000.0  left_only
# 1           NaN     NaN       NaN     NaN     NaN   72000.0  left_only
# 2           NaN     NaN       NaN     NaN     NaN   33000.0  left_only
# 3           NaN     NaN       NaN     NaN     NaN   56000.0  left_only
# 4           NaN     NaN       NaN     NaN     NaN   17000.0  left_only
# ...         ...     ...       ...     ...     ...       ...        ...
# 32300       NaN     NaN       NaN     NaN     NaN  123000.0  left_only
# 32305       NaN     NaN       NaN     NaN     NaN   63000.0  left_only
# 32310       NaN     NaN       NaN     NaN     NaN   64000.0  left_only
# 32315       NaN     NaN       NaN     NaN     NaN  728000.0  left_only
# 32316       NaN     NaN       NaN     NaN     NaN   54000.0  left_only
#
#         loop_fc
# 0      0.895055
# 1      0.993677
# 2      1.135605
# 3      0.920902
# 4      0.995276
# ...         ...
# 32300  0.873039
# 32305  0.828345
# 32310  0.924406
# 32315  1.195614
# 32316  0.876811
#
# [10844 rows x 53 columns]

# %%
loops_dist = pd.DataFrame(columns = cc.columns)
count_freq = (int(np.round(c)) for c in counts/sum(counts)*1000)

for i, count in enumerate(count_freq):
    print(i, count)
    if i > 0:
        loops_sub = cc2[(cc2['distance'] > bin_edges[i-1]) &
                                       (cc2['distance'] < bin_edges[i])].sample(count, random_state=16)
    else:
        loops_sub = cc2[(cc2['distance'] < bin_edges[i])].sample(count, random_state=16)
    
    loops_dist = pd.concat([loops_dist, loops_sub], axis=0)
# Out:
# 0 49
# 1 107
# 2 41
# 3 131
# 4 180
# 5 123
# 6 172
# 7 82
# 8 90
# 9 25

# %%
sns.histplot(loops_dist['distance'], bins=10)
# Out:
# <AxesSubplot:xlabel='distance', ylabel='Count'>

# %%
from scipy.stats import mannwhitneyu

# %%
cc2.columns
# Out:
# Index(['chr1', 'start1', 'end1', 'chr2', 'start2', 'end2', 'aavs1', 'nfe2',
#        'chrom1', 'width1', 'strand1', 'width2', 'strand2',
#        'anchor1_annotation', 'anchor2_annotation', 'class', 'coord1', 'coord2',
#        'coord', 'perturbation_name', 'triangle_score_P1',
#        'crosser_loop_scores_P1', 'crosser_loop_classes_P1',
#        'crosser_loop_coords_P1', 'ss_loop_scores_P1', 'ss_loop_classes_P1',
#        'ss_loop_coords_P1', 'agg_crosser_score_P1', 'agg_ss_score_P1',
#        'mean_crosser_score_P1', 'mean_ss_score_P1', 'triangle_score_P2',
#        'crosser_loop_scores_P2', 'crosser_loop_classes_P2',
#        'crosser_loop_coords_P2', 'ss_loop_scores_P2', 'ss_loop_classes_P2',
#        'ss_loop_coords_P2', 'agg_crosser_score_P2', 'agg_ss_score_P2',
#        'mean_crosser_score_P2', 'mean_ss_score_P2', 'quant', 'chr_diff',
#        'quant_diff', 'start1_lc', 'end1_lc', 'start2_lc', 'end2_lc', 'chrom2',
#        'distance', '_merge', 'loop_fc'],
#       dtype='object')

# %%
mannwhitneyu(loops_dist['loop_fc'].fillna(np.nan).dropna(), cc['loop_fc'].fillna(np.nan).dropna(), alternative='greater')
# Out:
# MannwhitneyuResult(statistic=63470.0, pvalue=0.06629850633408832)

# %%
tidy_df_cc = pd.DataFrame()
tidy_df_cc['loop_fc'] = cc['loop_fc'].values
tidy_df_cc['MM Status'] = 'Matchmaker'

tidy_df_cc2 = pd.DataFrame()
tidy_df_cc2['loop_fc'] = loops_dist['loop_fc'].values

tidy_df_cc2['MM Status'] = 'NotMatch'

tidy_df = pd.concat([tidy_df_cc, tidy_df_cc2], axis=0).reset_index(drop=True).dropna()

tidy_df['loop_fc'] = np.log2(pd.to_numeric(tidy_df['loop_fc'], errors='coerce'))

# %%
sns.violinplot(
    data=tidy_df,
    x='MM Status',
    y='loop_fc',
    hue='MM Status',
)

plt.savefig(os.path.join(savedir, "cc_loop_comp_nfe2.svg"))

# %%
sns.histplot(np.log2(cc['loop_fc'].fillna(np.nan).dropna()), stat='density', bins=40, fill=False, element='step', label='MM')
sns.histplot(np.log2(cc2['loop_fc'].fillna(np.nan).dropna()), stat='density', bins=40, fill=False, element='step', label='notMM')
plt.legend()
# Out:
# /home/varshini/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
