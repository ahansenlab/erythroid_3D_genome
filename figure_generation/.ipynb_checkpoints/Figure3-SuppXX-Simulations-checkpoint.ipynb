# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import glob
import re

plt.rcParams.update({
    "text.usetex": False})
plt.rcParams['svg.fonttype'] = 'none'
plt.rc('pdf',fonttype = 42)
plt.rcParams["ps.useafm"] = True

plt.rcParams['axes.grid'] = False
plt.rcParams['axes.spines.left'] = True
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.bottom'] = True
plt.rcParams.update({'font.size': 10})

plt.rcParams["legend.frameon"] = False

# %%
def parse_data(target_loop_idx, params, 
               type_to_report = 'inner', 
               report_params=['volume_density'],
              metric='obs'):
    master_data = []
    ftags=[]

    for i, row in params.iterrows():
        f = os.path.join(basedir, params.loc[i, 'result_file'])
        basename = os.path.basename(f).replace('.tsv', '')
        row_dict = {}

        df = pd.read_csv(f, sep='\t')
        if type_to_report == 'inner':
            loop_row = df[df['MM'] == 'inner'].iloc[target_loop_idx]
        elif type_to_report == 'EP':
            loop_row = df[df['loop_type'] == 'EP'].iloc[target_loop_idx]
        elif type_to_report == 'outer':
            loop_row = df[df['loop_type'] == 'EP'].iloc[target_loop_idx]
            
        row_dict['mean'] = loop_row[f'{metric}_mean']
        row_dict['se'] = loop_row[f'{metric}_se']
        master_data.append(row_dict)
        
        param_string=""
        for k in range(len(report_params)):
            param_string = f"{param_string}{params.loc[i, report_params[k]]}_"
        ftags.append(param_string)

    master_df = pd.DataFrame(master_data)
    master_df.index = ftags    
    
    return master_df, ftags


def error_propagate_se(df, idx_control):
    error_sq = (master_df['se']/master_df['mean'])**2
    const_err = (master_df['se'].loc[idx_control]/master_df['mean'].loc[idx_control])**2
    print(const_err)
    fc_se = np.sqrt(error_sq.values + const_err)
    
    return fc_se

# %%
basedir = "/mnt/md1/varshini/Blood/sim_density_processed_v2"
params = pd.read_csv(os.path.join(basedir, "mapping.tsv"), sep="\t").replace(np.nan, 0)
params['volume_density'] =params['volume_density'].replace(0, 0.3)

# %%
#select = params[params['vel_steps']=='(0.0025, 50)']
#select = select[~select["original_path"].str.contains("/mnt/md1/varshini/Blood/sim_data_velocity/2026-04-26 17:37:59.846865")]

# %%
params
# Out:
#      run_id  sim_id                                      original_path  \
# 0   run_000  sim_00  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 1   run_000  sim_01  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 2   run_002  sim_00  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 3   run_002  sim_01  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 4   run_002  sim_02  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 5   run_003  sim_00  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 6   run_004  sim_00  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 7   run_007  sim_00  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 8   run_007  sim_01  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 9   run_007  sim_02  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 10  run_007  sim_03  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 11  run_007  sim_04  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 12  run_007  sim_05  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 13  run_007  sim_06  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 14  run_007  sim_07  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 15  run_007  sim_08  /mnt/md1/varshini/Blood/sim_data_density/orig_...
#
#                  result_file                parameters_file  processivity  \
# 0   run_000_sim_00_loops.tsv  run_000_sim_00_parameters.txt           300
# 1   run_000_sim_01_loops.tsv  run_000_sim_01_parameters.txt           300
# 2   run_002_sim_00_loops.tsv  run_002_sim_00_parameters.txt           300
# 3   run_002_sim_01_loops.tsv  run_002_sim_01_parameters.txt           300
# 4   run_002_sim_02_loops.tsv  run_002_sim_02_parameters.txt           300
# 5   run_003_sim_00_loops.tsv  run_003_sim_00_parameters.txt           300
# 6   run_004_sim_00_loops.tsv  run_004_sim_00_parameters.txt           300
# 7   run_007_sim_00_loops.tsv  run_007_sim_00_parameters.txt           300
# 8   run_007_sim_01_loops.tsv  run_007_sim_01_parameters.txt           300
# 9   run_007_sim_02_loops.tsv  run_007_sim_02_parameters.txt           300
# 10  run_007_sim_03_loops.tsv  run_007_sim_03_parameters.txt           300
# 11  run_007_sim_04_loops.tsv  run_007_sim_04_parameters.txt           300
# 12  run_007_sim_05_loops.tsv  run_007_sim_05_parameters.txt           300
# 13  run_007_sim_06_loops.tsv  run_007_sim_06_parameters.txt           300
# 14  run_007_sim_07_loops.tsv  run_007_sim_07_parameters.txt           300
# 15  run_007_sim_08_loops.tsv  run_007_sim_08_parameters.txt           300
#
#     separations  ctcf_boost_factor  llp    h  loading_width  cohesins_per_mm  \
# 0           240                  4    2  0.4             16             64.0
# 1           240                  4    2  0.4             16             64.0
# 2           240                  4    2  0.4             16             64.0
# 3           240                  4    2  0.4             16             64.0
# 4           240                  4    2  0.4             16             64.0
# 5           240                  4    2  0.4             16              0.0
# 6           240                  4    2  0.4              2            256.0
# 7           240                  4    2  0.4             16             32.0
# 8           240                  4    2  0.4             32             32.0
# 9           240                  4    2  0.4              4             32.0
# 10          240                  4    2  0.4              8             32.0
# 11          240                  4    2  0.4             16             64.0
# 12          240                  4    2  0.4             32             64.0
# 13          240                  4    2  0.4              4             64.0
# 14          240                  4    2  0.4              8             64.0
# 15          240                  4    2  0.4              4              0.0
#
#     volume_density     vel_steps
# 0             0.15  (0.0025, 50)
# 1             0.45  (0.0025, 50)
# 2             0.15  (0.0025, 50)
# 3             0.45  (0.0025, 50)
# 4             0.60  (0.0025, 50)
# 5             0.60  (0.0025, 50)
# 6             0.30  (0.0025, 50)
# 7             0.30  (0.0025, 50)
# 8             0.30  (0.0025, 50)
# 9             0.30  (0.0025, 50)
# 10            0.30  (0.0025, 50)
# 11            0.30  (0.0025, 50)
# 12            0.30  (0.0025, 50)
# 13            0.30  (0.0025, 50)
# 14            0.30  (0.0025, 50)
# 15            0.30  (0.0025, 50)

# %%
select
# Out:
#     run_id  sim_id                                      original_path  \
# 0  run_003  sim_01  /mnt/md1/varshini/Blood/sim_data_velocity/2026...
# 1  run_004  sim_01  /mnt/md1/varshini/Blood/sim_data_velocity/2026...
# 4  run_009  sim_01  /mnt/md1/varshini/Blood/sim_data_velocity/2026...
# 5  run_010  sim_00  /mnt/md1/varshini/Blood/sim_data_velocity/2026...
#
#                 result_file                parameters_file  processivity  \
# 0  run_003_sim_01_loops.tsv  run_003_sim_01_parameters.txt           300
# 1  run_004_sim_01_loops.tsv  run_004_sim_01_parameters.txt           300
# 4  run_009_sim_01_loops.tsv  run_009_sim_01_parameters.txt           300
# 5  run_010_sim_00_loops.tsv  run_010_sim_00_parameters.txt           300
#
#    separations  ctcf_boost_factor  llp    h  loading_width  cohesins_per_mm  \
# 0          240                  4    2  0.4             16             64.0
# 1          240                  4    2  0.4             16             64.0
# 4          240                  4    2  0.4             16             64.0
# 5          240                  4    2  0.4             16             64.0
#
#    volume_density    vel_steps
# 0            0.45  (0.0025, 2)
# 1            0.60  (0.0025, 2)
# 4            0.30  (0.0025, 2)
# 5            0.15  (0.0025, 2)

# %%
def error_propagate_se(df, idx_control):
    error_sq = (master_df['se']/master_df['mean'])**2
    const_err = (master_df['se'].iloc[idx_control]/master_df['mean'].iloc[idx_control])**2
    fc_se = np.sqrt(error_sq.values + const_err)
    
    return fc_se

# %%
params
# Out:
#      run_id  sim_id                                      original_path  \
# 0   run_000  sim_00  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 1   run_000  sim_01  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 2   run_002  sim_00  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 3   run_002  sim_01  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 4   run_002  sim_02  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 5   run_003  sim_00  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 6   run_004  sim_00  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 7   run_007  sim_00  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 8   run_007  sim_01  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 9   run_007  sim_02  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 10  run_007  sim_03  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 11  run_007  sim_04  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 12  run_007  sim_05  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 13  run_007  sim_06  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 14  run_007  sim_07  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 15  run_007  sim_08  /mnt/md1/varshini/Blood/sim_data_density/orig_...
#
#                  result_file                parameters_file  processivity  \
# 0   run_000_sim_00_loops.tsv  run_000_sim_00_parameters.txt           300
# 1   run_000_sim_01_loops.tsv  run_000_sim_01_parameters.txt           300
# 2   run_002_sim_00_loops.tsv  run_002_sim_00_parameters.txt           300
# 3   run_002_sim_01_loops.tsv  run_002_sim_01_parameters.txt           300
# 4   run_002_sim_02_loops.tsv  run_002_sim_02_parameters.txt           300
# 5   run_003_sim_00_loops.tsv  run_003_sim_00_parameters.txt           300
# 6   run_004_sim_00_loops.tsv  run_004_sim_00_parameters.txt           300
# 7   run_007_sim_00_loops.tsv  run_007_sim_00_parameters.txt           300
# 8   run_007_sim_01_loops.tsv  run_007_sim_01_parameters.txt           300
# 9   run_007_sim_02_loops.tsv  run_007_sim_02_parameters.txt           300
# 10  run_007_sim_03_loops.tsv  run_007_sim_03_parameters.txt           300
# 11  run_007_sim_04_loops.tsv  run_007_sim_04_parameters.txt           300
# 12  run_007_sim_05_loops.tsv  run_007_sim_05_parameters.txt           300
# 13  run_007_sim_06_loops.tsv  run_007_sim_06_parameters.txt           300
# 14  run_007_sim_07_loops.tsv  run_007_sim_07_parameters.txt           300
# 15  run_007_sim_08_loops.tsv  run_007_sim_08_parameters.txt           300
#
#     separations  ctcf_boost_factor  llp    h  loading_width  cohesins_per_mm  \
# 0           240                  4    2  0.4             16             64.0
# 1           240                  4    2  0.4             16             64.0
# 2           240                  4    2  0.4             16             64.0
# 3           240                  4    2  0.4             16             64.0
# 4           240                  4    2  0.4             16             64.0
# 5           240                  4    2  0.4             16              0.0
# 6           240                  4    2  0.4              2            256.0
# 7           240                  4    2  0.4             16             32.0
# 8           240                  4    2  0.4             32             32.0
# 9           240                  4    2  0.4              4             32.0
# 10          240                  4    2  0.4              8             32.0
# 11          240                  4    2  0.4             16             64.0
# 12          240                  4    2  0.4             32             64.0
# 13          240                  4    2  0.4              4             64.0
# 14          240                  4    2  0.4              8             64.0
# 15          240                  4    2  0.4              4              0.0
#
#     volume_density     vel_steps
# 0             0.15  (0.0025, 50)
# 1             0.45  (0.0025, 50)
# 2             0.15  (0.0025, 50)
# 3             0.45  (0.0025, 50)
# 4             0.60  (0.0025, 50)
# 5             0.60  (0.0025, 50)
# 6             0.30  (0.0025, 50)
# 7             0.30  (0.0025, 50)
# 8             0.30  (0.0025, 50)
# 9             0.30  (0.0025, 50)
# 10            0.30  (0.0025, 50)
# 11            0.30  (0.0025, 50)
# 12            0.30  (0.0025, 50)
# 13            0.30  (0.0025, 50)
# 14            0.30  (0.0025, 50)
# 15            0.30  (0.0025, 50)

# %%
select = params[((params['cohesins_per_mm']==64) | (params['cohesins_per_mm']==0)) &
               (params['volume_density']==0.3)]

# %%
params
# Out:
#      run_id  sim_id                                      original_path  \
# 0   run_000  sim_00  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 1   run_000  sim_01  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 2   run_002  sim_00  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 3   run_002  sim_01  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 4   run_002  sim_02  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 5   run_003  sim_00  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 6   run_004  sim_00  /mnt/md1/varshini/Blood/sim_data_density/2026-...
# 7   run_007  sim_00  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 8   run_007  sim_01  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 9   run_007  sim_02  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 10  run_007  sim_03  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 11  run_007  sim_04  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 12  run_007  sim_05  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 13  run_007  sim_06  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 14  run_007  sim_07  /mnt/md1/varshini/Blood/sim_data_density/orig_...
# 15  run_007  sim_08  /mnt/md1/varshini/Blood/sim_data_density/orig_...
#
#                  result_file                parameters_file  processivity  \
# 0   run_000_sim_00_loops.tsv  run_000_sim_00_parameters.txt           300
# 1   run_000_sim_01_loops.tsv  run_000_sim_01_parameters.txt           300
# 2   run_002_sim_00_loops.tsv  run_002_sim_00_parameters.txt           300
# 3   run_002_sim_01_loops.tsv  run_002_sim_01_parameters.txt           300
# 4   run_002_sim_02_loops.tsv  run_002_sim_02_parameters.txt           300
# 5   run_003_sim_00_loops.tsv  run_003_sim_00_parameters.txt           300
# 6   run_004_sim_00_loops.tsv  run_004_sim_00_parameters.txt           300
# 7   run_007_sim_00_loops.tsv  run_007_sim_00_parameters.txt           300
# 8   run_007_sim_01_loops.tsv  run_007_sim_01_parameters.txt           300
# 9   run_007_sim_02_loops.tsv  run_007_sim_02_parameters.txt           300
# 10  run_007_sim_03_loops.tsv  run_007_sim_03_parameters.txt           300
# 11  run_007_sim_04_loops.tsv  run_007_sim_04_parameters.txt           300
# 12  run_007_sim_05_loops.tsv  run_007_sim_05_parameters.txt           300
# 13  run_007_sim_06_loops.tsv  run_007_sim_06_parameters.txt           300
# 14  run_007_sim_07_loops.tsv  run_007_sim_07_parameters.txt           300
# 15  run_007_sim_08_loops.tsv  run_007_sim_08_parameters.txt           300
#
#     separations  ctcf_boost_factor  llp    h  loading_width  cohesins_per_mm  \
# 0           240                  4    2  0.4             16             64.0
# 1           240                  4    2  0.4             16             64.0
# 2           240                  4    2  0.4             16             64.0
# 3           240                  4    2  0.4             16             64.0
# 4           240                  4    2  0.4             16             64.0
# 5           240                  4    2  0.4             16              0.0
# 6           240                  4    2  0.4              2            256.0
# 7           240                  4    2  0.4             16             32.0
# 8           240                  4    2  0.4             32             32.0
# 9           240                  4    2  0.4              4             32.0
# 10          240                  4    2  0.4              8             32.0
# 11          240                  4    2  0.4             16             64.0
# 12          240                  4    2  0.4             32             64.0
# 13          240                  4    2  0.4              4             64.0
# 14          240                  4    2  0.4              8             64.0
# 15          240                  4    2  0.4              4              0.0
#
#     volume_density     vel_steps
# 0             0.15  (0.0025, 50)
# 1             0.45  (0.0025, 50)
# 2             0.15  (0.0025, 50)
# 3             0.45  (0.0025, 50)
# 4             0.60  (0.0025, 50)
# 5             0.60  (0.0025, 50)
# 6             0.30  (0.0025, 50)
# 7             0.30  (0.0025, 50)
# 8             0.30  (0.0025, 50)
# 9             0.30  (0.0025, 50)
# 10            0.30  (0.0025, 50)
# 11            0.30  (0.0025, 50)
# 12            0.30  (0.0025, 50)
# 13            0.30  (0.0025, 50)
# 14            0.30  (0.0025, 50)
# 15            0.30  (0.0025, 50)

# %%
idx = 1
master_df, ftags = parse_data(idx, select, type_to_report='inner', 
                              report_params=["cohesins_per_mm", "volume_density", "loading_width"],
                             metric='obs')

idx_control=-1

master_df['fc_mean']=np.log2(master_df['mean']/master_df['mean'].iloc[idx_control])
master_df['propagated_se']=error_propagate_se(master_df, idx_control=idx_control)
master_df.plot(
        kind='bar',
        y='fc_mean',
        yerr='propagated_se', 
        capsize=4, 
        edgecolor='black',
        alpha=0.8,
        linewidth=2,
    figsize=(5, 3)
    )
    
# Rotate x-labels if they are squished
plt.xticks(rotation=0)
plt.ylabel('Log2FC Contact Over Baseline')
#plt.ylim([0, 0.25])
plt.tight_layout()
#plt.savefig(os.path.join(savedir, f"loop_{loop_idx}_fc.svg"))
plt.title(f"Matchmaker # {idx}")
plt.show()

# %%
idx = 2
master_df, ftags = parse_data(idx, select, type_to_report='outer', 
                              report_params=["cohesins_per_mm", "volume_density", "loading_width"],
                             metric='obs')

idx_control=-1

master_df['fc_mean']=np.log2(master_df['mean']/master_df['mean'].iloc[idx_control])
master_df['propagated_se']=error_propagate_se(master_df, idx_control=idx_control)
master_df.plot(
        kind='bar',
        y='fc_mean',
        yerr='propagated_se', 
        capsize=4, 
        edgecolor='black',
        alpha=0.8,
        linewidth=2,
    figsize=(8, 3)
    )
    
# Rotate x-labels if they are squished
plt.xticks(rotation=0)
plt.ylabel('Log2FC Contact Over Baseline')
#plt.ylim([-0.7, 0.7])
plt.tight_layout()
#plt.savefig(os.path.join(savedir, f"loop_{loop_idx}_fc.svg"))
plt.title(f"Matchmaker # {idx}")
plt.show()
