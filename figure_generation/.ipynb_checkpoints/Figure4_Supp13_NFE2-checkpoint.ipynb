# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import random

from scipy.stats import mannwhitneyu, false_discovery_control, ttest_ind, kstest
from matplotlib.patches import Patch

import cooler 
import cooltools
from matplotlib.colors import LogNorm
import cooltools.lib.plotting
from matplotlib.backends.backend_pdf import PdfPages

from functools import reduce 

# %cd /home/varshini/uc_analyses/
import utils, loops_txn, matchmaker_functions
# %cd /home/varshini/LoopCall_Analysis_Scripts

import ast
from sklearn import feature_selection
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
# Out:
# /home/varshini/uc_analyses
# /home/varshini/LoopCall_Analysis_Scripts
# /home/varshini/microc_analyses/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# plot formatting
plt.rcParams.update({
    "text.usetex": False})
plt.rcParams['svg.fonttype'] = 'none'
plt.rc('pdf',fonttype = 42)
plt.rcParams["ps.useafm"] = True

plt.rcParams['axes.grid'] = False
plt.rcParams['axes.spines.left'] = True
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.bottom'] = True
plt.rcParams.update({'font.size': 18})

plt.rcParams["legend.frameon"] = False

# %%
datapath = '/mnt/md0/varshini/Analysis/Blood/complete_analyses/matchmakers/matchmaker_scores/'
savedir="/mnt/md0/varshini/Analysis/Blood/figs_v1/figure4"

# %%
phases = ['AAVS1_P3', 'NFE2_P3']
dists = [25000, 50000, 100000, 200000]

cooler_path = '/mnt/coldstorage/Varshmallow/Adipose_Blood_Merged/sankaran'
cooler_names = [os.path.join(cooler_path, f"Sankaran_{p}merged.250.mcool") for p in phases]
LIST_COLS = ['crosser_loop_scores', 'crosser_loop_classes',
            'ss_loop_scores', 'ss_loop_classes']

# %%
dist= dists[2]
diff_thresh=10000

# %%
nametag = "tf_acrs_sorted_enhancernotpromoternotctcf"
og_mm = pd.read_csv(f"/mnt/md0/varshini/Analysis/Blood/complete_analyses/matchmakers/{nametag}_{dist//1000}kb_merge{diff_thresh/1000}kb_clus.bed",
                   sep="\t")
og_mm = og_mm[['chr', 'coord', 'quant']]

# %%
# multiple phases
match_scores = matchmaker_functions.load_matchmaker_scores_phase(datapath, phases, nametag = f"nfe2_only_tf", list_cols=LIST_COLS,
                                            dist=dist, difference_threshold=diff_thresh,triangle_score_cols=['triangle_score_P1','triangle_score_P2']).dropna(subset='triangle_score_P1')

match_scores_comp = matchmaker_functions.load_matchmaker_scores_phase(datapath, phases, nametag = f"gfi1b_only_eryth", list_cols=LIST_COLS,
                                            dist=dist, difference_threshold=diff_thresh,triangle_score_cols=['triangle_score_P1','triangle_score_P2']).dropna(subset='triangle_score_P1')


match_scores_control = matchmaker_functions.load_matchmaker_scores_phase(datapath, phases, nametag = f"shuffled_sites", list_cols=LIST_COLS,
                                            dist=dist, difference_threshold=diff_thresh,triangle_score_cols=['triangle_score_P1','triangle_score_P2']).dropna(subset='triangle_score_P1').sample(1000, random_state=1)

# %%
match_scores
# Out:
#                  chr        coord perturbation_name  triangle_score_P1  \
# locus
# chr1:6317423    chr1    6317423.0              NFE2           1.424136
# chr1:9275701    chr1    9275701.5              NFE2           0.903714
# chr1:10415493   chr1   10415493.5              NFE2           1.252600
# chr1:10459322   chr1   10459322.5              NFE2           1.254360
# chr1:12496644   chr1   12496644.5              NFE2           1.371587
# ...              ...          ...               ...                ...
# chrX:55003094   chrX   55003094.0              NFE2           0.985873
# chrX:72532503   chrX   72532503.0              NFE2           0.944656
# chrX:119427490  chrX  119427490.0              NFE2           1.074473
# chrX:124698899  chrX  124698899.0              NFE2           1.305031
# chrX:125399069  chrX  125399069.5              NFE2           1.486328
#
#                                            crosser_loop_scores_P1  \
# locus
# ...

# %%
def do_quant(match_scores, n_quant = 4):
    cleaned_scores = match_scores[[f"triangle_score_P{i}" for i in (range(1, len(phases)+1))]].dropna()
    cleaned_scores = cleaned_scores[(cleaned_scores != 0).all(axis=1)]
    
    grp = matchmaker_functions.do_kmeans(cleaned_scores, n_quant, rand=42)
    cleaned_scores = matchmaker_functions.plot_clusters(cleaned_scores, grp)
    
    inds = cleaned_scores.groupby('g').agg('triangle_score_P1').mean().sort_values().index.tolist()
    ind_dict = dict(zip(inds, np.arange(n_quant)))
    
    cleaned_scores['quant'] = cleaned_scores['g'].map(ind_dict)
    cleaned_scores.drop('g', inplace=True, axis=1)
    
    return cleaned_scores

def merge_match_asof(match_scores_grouped, og_mm, max_diff=10_000):
    chrom_order = [f'chr{i}' for i in range(1, 23)] + ['chrX', 'chrY']

    out = []

    for chrom in chrom_order:

        left = (
            match_scores_grouped[match_scores_grouped['chr'] == chrom]
            .sort_values('coord')
        )

        right = (
            og_mm[og_mm['chr'] == chrom]
            .sort_values('coord')
        )

        if len(left) == 0 or len(right) == 0:
            continue

        merged_chr = pd.merge_asof(
            left,
            right,
            on='coord',
            direction='nearest',
            tolerance=max_diff,
            suffixes=('', '_diff')
        )

        out.append(merged_chr)

    merged = pd.concat(out, ignore_index=True)
    return merged

# %%
cleaned_scores = do_quant(match_scores)
match_scores_grouped = match_scores.merge(cleaned_scores['quant'], how='inner', left_index=True, right_index=True)
# Out:
#                 triangle_score_P1  triangle_score_P2  g
# locus
# chr2:96617636            1.246415           1.181732  0
# chr5:31085054            1.012425           1.111146  0
# chr16:15885894           1.109545           1.115475  0
# chr16:11233258           1.082423           1.066103  0
# chr16:2497453            1.082489           1.098861  0
# ...                           ...                ... ..
# chr21:32516953           1.676330           1.613405  3
# chr5:134466851           1.651765           1.553073  3
# chr21:33065158           2.072954           2.026677  3
# chr5:72227127            1.756815           1.716099  3
# chr12:4215521            1.725025           1.760836  3
#
# [875 rows x 3 columns]

# %%
merged = merge_match_asof(match_scores_grouped, og_mm)

# %%
nametag
# Out:
# 'tf_acrs_sorted_enhancernotpromoternotctcf'

# %%
savedir=f"/mnt/md0/varshini/Analysis/Blood/complete_analyses/matchmakers/nfe2_only_tf_{dist//1000}kb_merge{diff_thresh/1000}kb_clus.bed"
#merged.to_csv(savedir, sep="\t", index=False)

# %%
merged[merged['quant_diff'].isna()]
# Out:
#        chr        coord perturbation_name  triangle_score_P1  \
# 28    chr1   61196773.0              NFE2           1.273981
# 108   chr2   26353053.0              NFE2           1.163222
# 132   chr2   96148707.5              NFE2           1.262541
# 185   chr3   53236351.5              NFE2           1.095233
# 206   chr3  129050482.5              NFE2           1.693420
# 269   chr5   14865819.0              NFE2           1.082215
# 317   chr6   15091594.5              NFE2           1.529982
# 332   chr6   42039718.5              NFE2           0.505402
# 336   chr6   43811273.5              NFE2           1.263945
# 355   chr6  139434052.5              NFE2           1.342798
# 389   chr7   69412760.0              NFE2           1.038605
# 417   chr8    1745530.5              NFE2           1.528803
# 460   chr9   19168669.5              NFE2           1.143278
# 527  chr10  110082068.0              NFE2           1.109933
# ...

# %%
## merging analyses 

test_phase = 'P2'
control_phase = 'P1'
merged_df = matchmaker_functions.merged_attrs(merged[merged['quant_diff']==2], test_phase, control_phase)
merged_df_control = matchmaker_functions.merged_attrs(match_scores_control, test_phase, control_phase)

print(merged_df['triangle_fc'].mean())

plt.figure(figsize=(8,6))
sns.histplot(merged_df['triangle_fc'], stat='density', common_norm=False,
                     fill=False, element="step", color='#ee7733',label='Fold Change in Enh.')
sns.histplot(merged_df_control['triangle_fc'], stat='density', common_norm=False,
                     fill=False, element="step", color='k', label='Fold Change in Random Sites')
plt.xlabel('Fold Change in Matchmaker Score (NFE2/AAVS1)')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# 0.975001678055127

# %%
from scipy.stats import mannwhitneyu

mannwhitneyu(merged_df['triangle_score_P2'], merged_df['triangle_score_P1'])
# Out:
# MannwhitneyuResult(statistic=29994.0, pvalue=0.012519167009286725)

# %%
# savedir=f"/mnt/md0/varshini/Analysis/Blood/complete_analyses/matchmakers/nfe2_tf_only_{dist//1000}kb_merge{diff_thresh/1000}kb_clus.bed"
match_scores_grouped.to_csv(savedir, sep="\t", index=False)

# %% [markdown]
# ## Are the most changed flanking scores driven by changes in looping or changes in overall contact frequency?

# %%
test_phase = 'P2'
control_phase = 'P1'
merged_df = matchmaker_functions.merged_attrs(match_scores, test_phase, control_phase)
merged_df_control = matchmaker_functions.merged_attrs(match_scores_control, test_phase, control_phase)

# %%
basedir = '/mnt/md1/varshini/sankaran_tfko_microc/full_merged_files/'
nfe2_ko = utils.get_clr(os.path.join(basedir, 'NFE2_P3_microc.50.mcool'), 5000)
nfe2_aavs1 = utils.get_clr(os.path.join(basedir, 'AAVS1_P3_microc.50.mcool'), 5000)

# %%
merged_df
# Out:
#                   chr        coord perturbation_name  triangle_score_P1  \
# locus
# chr5:54738314    chr5   54738314.0              NFE2           1.493846
# chr6:490558      chr6     490558.5              NFE2           1.233976
# chr8:58842283    chr8   58842283.5              NFE2           1.284148
# chr9:5494067     chr9    5494067.5              NFE2           1.702955
# chr2:8229784     chr2    8229784.0              NFE2           1.210826
# ...               ...          ...               ...                ...
# chr8:87686753    chr8   87686753.0              NFE2           1.050748
# chr5:173778956   chr5  173778956.5              NFE2           1.149310
# chr18:48090863  chr18   48090863.5              NFE2           1.320579
# chr4:48496083    chr4   48496083.5              NFE2           0.777636
# chr3:173493264   chr3  173493264.5              NFE2           1.181174
#
#                                            crosser_loop_scores_P1  \
# locus
# ...

# %%
sns.histplot(merged_df[f'agg_crosser_score_{control_phase}'], color='k')
sns.histplot(merged_df[f'agg_crosser_score_{test_phase}'],color='r')


plt.show()
merged_df['ss_fc'].median()
# Out:
# 0.9803715488447059

# %%
sns.histplot(merged_df[f'triangle_score_{test_phase}'], common_norm=False, stat='density', 
                     fill=False, element="step", color='#ee7733')
sns.histplot(merged_df[f'triangle_score_{control_phase}'], common_norm=False, stat='density', 
                     fill=False, element="step", color='k')
plt.xlim([0, 3])
plt.show()

# %%
plt.scatter(merged_df_control[f'triangle_score_{test_phase}'], merged_df_control[f'triangle_score_{control_phase}'], alpha=0.2, color='k')
plt.scatter(merged_df[f'triangle_score_{test_phase}'], merged_df[f'triangle_score_{control_phase}'], alpha=0.1)

plt.plot(np.linspace(0, 3, 50), np.linspace(0, 3, 50), color='k', ls='--')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(merged_df['triangle_fc'], stat='density', common_norm=False,
                     fill=False, element="step", color='#ee7733',label='Fold Change in NFE2 Enh.')
sns.histplot(merged_df_control['triangle_fc'], stat='density', common_norm=False,
                     fill=False, element="step", color='k', label='Fold Change in Random Sites')
#plt.xlim([0.75, 1.3])
plt.xlabel('Fold Change in Matchmaker Score (NFE2/AAVS1)')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
merged_df['triangle_fc'].median()
# Out:
# 0.9848355467949278

# %%
np.linspace(0, 3, 50)
# Out:
# array([0.        , 0.06122449, 0.12244898, 0.18367347, 0.24489796,
#        0.30612245, 0.36734694, 0.42857143, 0.48979592, 0.55102041,
#        0.6122449 , 0.67346939, 0.73469388, 0.79591837, 0.85714286,
#        0.91836735, 0.97959184, 1.04081633, 1.10204082, 1.16326531,
#        1.2244898 , 1.28571429, 1.34693878, 1.40816327, 1.46938776,
#        1.53061224, 1.59183673, 1.65306122, 1.71428571, 1.7755102 ,
#        1.83673469, 1.89795918, 1.95918367, 2.02040816, 2.08163265,
#        2.14285714, 2.20408163, 2.26530612, 2.32653061, 2.3877551 ,
#        2.44897959, 2.51020408, 2.57142857, 2.63265306, 2.69387755,
#        2.75510204, 2.81632653, 2.87755102, 2.93877551, 3.        ])

# %%
sns.histplot(merged_df['crosser_fc'], color='#CC3311')
plt.xlabel('Crosser Loop Fold Change, NFE2 KO/AAVS1')
plt.xlim([0.5, 2])
#plt.savefig(os.path.join(savedir, 'crosser_loop_fc_hist.svg'))
plt.show()
print(merged_df['crosser_fc'].mean())
sns.histplot(merged_df['ss_fc'])
plt.show()
print(merged_df['ss_fc'].mean())
# Out:
# 0.9638389777812737
# 0.9761634425793608

# %%
def get_locus_from_coord(row, flank=200000):
    return f"{row['chr']}:{int(row['coord'])-flank}-{int(row['coord'])+flank}"

# %%
locus = merged_df.sort_values(by='ss_fc').apply(get_locus_from_coord, axis=1)

# %%
merged_df.sort_values(by='ss_fc')[:50]
# Out:
#                    chr        coord perturbation_name  triangle_score_P1  \
# locus
# chr5:178684014    chr5  178684014.0              NFE2           1.262672
# chr17:38463572   chr17   38463572.5              NFE2           1.719630
# chr7:32669303     chr7   32669303.0              NFE2           0.915055
# chr20:19275556   chr20   19275556.5              NFE2           1.211622
# chr5:91280612     chr5   91280612.0              NFE2           1.327921
# chr10:74011663   chr10   74011663.0              NFE2           1.862398
# chr1:167548604    chr1  167548604.0              NFE2           0.825623
# chr6:149129895    chr6  149129895.0              NFE2           1.617422
# chr13:46532077   chr13   46532077.5              NFE2           0.981656
# chr11:121252157  chr11  121252157.5              NFE2           1.019391
# chr1:35674299     chr1   35674299.5              NFE2           1.576137
# chr10:114943144  chr10  114943144.5              NFE2           1.403096
# ...

# %%
clean_x = merged_df.dropna(subset=['triangle_fc', 'crosser_fc'])['triangle_fc'].values.reshape(-1, 1)
clean_y = merged_df.dropna(subset=['triangle_fc', 'crosser_fc'])['crosser_fc'].values.reshape(-1, 1)
reg_crosser = LinearRegression().fit(clean_x, 
                                     clean_y)
interc = reg_crosser.intercept_
coef = reg_crosser.coef_
pred_y = reg_crosser.predict(clean_x)


clean_x_ss = merged_df.dropna(subset=['triangle_fc', 'ss_fc'])['triangle_fc'].values.reshape(-1, 1)
clean_y_ss = merged_df.dropna(subset=['triangle_fc', 'ss_fc'])['ss_fc'].values.reshape(-1, 1)
reg_ss = LinearRegression().fit(clean_x_ss, 
                                    clean_y_ss )
interc_ss = reg_ss.intercept_
coef_ss = reg_ss.coef_

pred_y_ss = reg_ss.predict(clean_x_ss)

# %%
r2_score(clean_y, pred_y)
# Out:
# 0.29155705198720727

# %%
r2_score(clean_y_ss, pred_y_ss)
# Out:
# 0.0014594928514346517

# %%
feature_selection.r_regression(clean_x_ss, clean_y_ss)
# Out:
# /home/varshini/microc_analyses/lib/python3.9/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([0.03820331])

# %%
# triangle fc vs ss 
plt.scatter(merged_df['triangle_fc'], merged_df['crosser_fc'], alpha=0.2, color='#CC3311')
plt.xlabel('Fold Change in Matchmaker Score', fontsize=16)
plt.ylabel('Fold Change in Crosser Score', fontsize=16)
plt.plot(clean_x, pred_y, linestyle='--', color='k')
plt.ylim([0.4, 1.5])
plt.xlim([0.8, 1.2])
plt.title('Crosser Scores vs. Matchmaker Scores')
#plt.savefig(os.path.join(savedir, 'crosser_match_fc_corr.svg'))
plt.show()



plt.scatter(merged_df['triangle_fc'], merged_df['ss_fc'], alpha=0.2, color='#33BBEE')
plt.plot(clean_x_ss, pred_y_ss, linestyle='--', color='k')

plt.xlabel('Fold Change in Matchmaker Score',fontsize=16)
plt.ylabel('Fold Change in Same-Side Score', fontsize=16)
plt.title('Same-Side Scores vs. Matchmaker Scores')
#plt.ylim([0.5, 1.5])
#plt.ylim([0.7, 1.5])
#plt.savefig(os.path.join(savedir, 'ss_match_fc_corr.svg'))
plt.show()

# %%
## instead of quantiling, now cluster group like the other mms
from sklearn import cluster
def do_kmeans(df, nclus, rand=None):
    clus = cluster.KMeans(n_clusters=nclus, random_state=rand)
    cluster_labels = clus.fit_predict(df)

    X_new = clus.transform(df)
    centroids = clus.cluster_centers_

    f = lambda xrow: np.where(xrow == min(xrow))[0][0]
    # find minimum distance for each point and assign it cluster label
    # X_new: ndarray of shape (n_samples, n_clusters)
    grp = np.array(np.apply_along_axis(f, axis=1, arr=X_new))

    return grp

def plot_clusters(df, grp=None, writepath=None):
    if grp is None:
        sns.heatmap(df)
        plt.show()
    else:
        cm = dict(zip(np.unique(grp), sns.color_palette('hls', n_colors=len(np.unique(grp)))))
        df['g'] = grp
        df.sort_values(by='g', inplace=True)
        print(df)
        sns.clustermap(df.drop(columns='g', axis=1), row_colors=[cm[g] for g in df['g']], 
                       row_cluster=False, col_cluster=False, cmap='coolwarm', center=1)

        if writepath is not None:
            plt.savefig(f"{writepath}.svg", dpi=300, format='svg')
        else:
            plt.show()

    return df
cleaned_scores = match_scores[[f"triangle_score_P{i}" for i in [1, 2]]].dropna()
cleaned_scores=cleaned_scores[(cleaned_scores["triangle_score_P1"]>0)&(cleaned_scores["triangle_score_P2"]>0)]
grp = do_kmeans(cleaned_scores, 4, rand=4)
cleaned_scores = plot_clusters(cleaned_scores, grp)
# Out:
#                 triangle_score_P1  triangle_score_P2  g
# locus
# chr2:96617636            1.246415           1.181732  0
# chr16:49620659           1.153133           1.116719  0
# chr16:25048807           1.068749           1.032426  0
# chr5:62261788            1.111208           1.232262  0
# chr16:15885894           1.109545           1.115475  0
# ...                           ...                ... ..
# chr6:119147407           0.686577           0.686846  3
# chr12:79784643           0.799937           0.703715  3
# chr19:48976319           0.519086           0.525903  3
# chr19:32708919           0.874176           0.919074  3
# chr2:209324510           0.853146           0.815417  3
#
# [875 rows x 3 columns]

# %%
# now rename clusters according to MM score 
inds = cleaned_scores.groupby('g').agg('triangle_score_P1').mean().sort_values().index.tolist()
ind_dict = dict(zip(inds, np.arange(4)))

cleaned_scores['quant'] = cleaned_scores['g'].map(ind_dict)
cleaned_scores.drop('g', inplace=True, axis=1)

match_scores_grouped = match_scores.merge(cleaned_scores['quant'], how='inner', left_index=True, right_index=True)

# %%
merged_df['quantile'] = pd.qcut(merged_df[f"triangle_fc"], 20, labels=False)

# %%
merged_df_control[merged_df_control['triangle_fc']<0.9][f"triangle_score_{control_phase}"].mean()
# Out:
# 1.161634704135913

# %%
merged_df_control[merged_df_control['triangle_fc']>0.9][f"triangle_score_{control_phase}"].mean()
# Out:
# 1.065855958246688

# %%
sns.histplot(merged_df[(merged_df['triangle_fc']>0.9)&(merged_df['triangle_fc']<1)][f"triangle_score_{control_phase}"], color='k', stat='density')
sns.histplot(merged_df[merged_df['triangle_fc']<0.9][f"triangle_score_{control_phase}"], color='r', stat='density')
plt.show()

# %%
print(merged_df[merged_df['triangle_fc']<0.9][f"triangle_score_{control_phase}"].mean())
print(merged_df[(merged_df['triangle_fc']>0.9)&(merged_df['triangle_fc']<1)][f"triangle_score_{control_phase}"].mean())
# Out:
# 1.2209176528640093
# 1.1936490045823898

# %%
sns.histplot(merged_df_control[(merged_df_control['triangle_fc']>0.9)&(merged_df_control['triangle_fc']<1)][f"triangle_score_{control_phase}"], color='k', stat='density')
sns.histplot(merged_df_control[merged_df_control['triangle_fc']<0.9][f"triangle_score_{control_phase}"], color='r', stat='density')
plt.show()

# %%
plt.scatter(merged_df['triangle_fc'], merged_df[f"triangle_score_{control_phase}"], alpha=0.1, color='#CC3311')
plt.xlim(0.5, 1.25)
# Out:
# (0.5, 1.25)

# %%
# triangle fc vs ss 
plt.scatter(merged_df[f'triangle_score_{control_phase}'], merged_df[f'ss_crosser_ratio_control'], alpha=0.1)
plt.axhline(1, color='k', ls='--')
plt.axvline(1, color='k', ls='--')
#plt.ylim([0.5, 15])
plt.yscale('log')
plt.show()

plt.scatter(merged_df[f'triangle_score_{test_phase}'], merged_df[f'ss_crosser_ratio_test'], alpha=0.1)
plt.axhline(1, color='k', ls='--')
plt.axvline(1, color='k', ls='--')
plt.yscale('log')
plt.show()

plt.scatter(merged_df[f'triangle_fc'], merged_df[f'ratio_fc'], alpha=0.1)
plt.show()

# %%
# triangle fc vs ss 
plt.scatter(merged_df[f'triangle_score_{control_phase}'], 
            merged_df[f'agg_crosser_score_{control_phase}'], alpha=0.1, color='#CC3311')
plt.axhline(1, color='k', ls='--')
plt.axvline(1, color='k', ls='--')
plt.xlabel('Matchmaker Score',fontsize=16)
plt.ylabel('Aggregate Crosser Loop Score',fontsize=16)
plt.title('Crosser Loop Score vs. Matchmaker Score')
# plt.savefig(os.path.join(savedir, 'cross_match_all_corr.svg'))
plt.xlim([0, 3])
plt.show()

plt.axhline(1, color='k', ls='--')
plt.axvline(1, color='k', ls='--')
plt.scatter(merged_df[f'triangle_score_{control_phase}'], merged_df[f'agg_ss_score_{control_phase}'], 
            alpha=0.1,  color='#33BBEE')
plt.xlabel('Matchmaker Score',fontsize=16)
plt.ylabel('Aggregate Same-Side Loop Score',fontsize=16)
plt.title('Same-Side Loop Score vs. Matchmaker Score')
# plt.savefig(os.path.join(savedir, 'ss_match_all_corr.svg'))
plt.xlim([0, 3])
plt.show()

# %%
merged_df
# Out:
#                   chr        coord           perturbation_name  \
# locus
# chr5:68116594    chr5   68116594.5  enhancernotpromoternotctcf
# chr15:58332242  chr15   58332242.0  enhancernotpromoternotctcf
# chr12:94699967  chr12   94699967.5  enhancernotpromoternotctcf
# chr6:168272614   chr6  168272614.5  enhancernotpromoternotctcf
# chr10:21208813  chr10   21208813.5  enhancernotpromoternotctcf
# ...               ...          ...                         ...
# chr2:113700539   chr2  113700539.5  enhancernotpromoternotctcf
# chr7:11346326    chr7   11346326.0  enhancernotpromoternotctcf
# chr16:46524005  chr16   46524005.5  enhancernotpromoternotctcf
# chr5:50352777    chr5   50352777.5  enhancernotpromoternotctcf
# chr11:3614335   chr11    3614335.0  enhancernotpromoternotctcf
#
#                 triangle_score_P1                  crosser_loop_scores_P1  \
# locus
# chr5:68116594            1.605671                                      []
# ...

# %%
crosser_cols = [
    x
    for p in [test_phase, control_phase]
    for x in (
        f"crosser_loop_scores_{p}",
        f"crosser_loop_classes_{p}",
        f"crosser_loop_coords_{p}",
    )
]

ss_cols = [
    x
    for p in [test_phase, control_phase]
    for x in (
        f"ss_loop_scores_{p}",
        f"ss_loop_classes_{p}",
        f"ss_loop_coords_{p}",
    )
]

# %%
crosser_exploded = merged_df.explode(crosser_cols)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2482265/1014623509.py in ?()
# ----> 1 crosser_exploded = merged_df.explode(crosser_cols)
#
# ~/microc_analyses/lib/python3.9/site-packages/pandas/core/frame.py in ?(self, column, ignore_index)
#    9848             mylen = lambda x: len(x) if (is_list_like(x) and len(x) > 0) else 1
#    9849             counts0 = self[columns[0]].apply(mylen)
#    9850             for c in columns[1:]:
#    9851                 if not all(counts0 == self[c].apply(mylen)):
# -> 9852                     raise ValueError("columns must have matching element counts")
#    9853             result = DataFrame({c: df[c].explode() for c in columns})
#    9854         result = df.drop(columns, axis=1).join(result)
#    9855         if ignore_index:
#
# ValueError: columns must have matching element counts

# %%
merged_df
# Out:
#                   chr        coord           perturbation_name  \
# locus
# chr5:68116594    chr5   68116594.5  enhancernotpromoternotctcf
# chr15:58332242  chr15   58332242.0  enhancernotpromoternotctcf
# chr12:94699967  chr12   94699967.5  enhancernotpromoternotctcf
# chr6:168272614   chr6  168272614.5  enhancernotpromoternotctcf
# chr10:21208813  chr10   21208813.5  enhancernotpromoternotctcf
# ...               ...          ...                         ...
# chr2:113700539   chr2  113700539.5  enhancernotpromoternotctcf
# chr7:11346326    chr7   11346326.0  enhancernotpromoternotctcf
# chr16:46524005  chr16   46524005.5  enhancernotpromoternotctcf
# chr5:50352777    chr5   50352777.5  enhancernotpromoternotctcf
# chr11:3614335   chr11    3614335.0  enhancernotpromoternotctcf
#
#                 triangle_score_P1                  crosser_loop_scores_P1  \
# locus
# chr5:68116594            1.605671                                      []
# ...

# %%
crosser_exploded.iloc[:10, :]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[180], line 1
# ----> 1 crosser_exploded.iloc[:10, :]
#
# NameError: name 'crosser_exploded' is not defined

# %%
group_cols = ["chr", "coord", "triangle_fc"]          # shared features
agg_fn = np.max                       # swap freely
def tri(p): return f"triangle_score_{p}"
def cross(p): return f"crosser_loop_scores_{p}"
def cls(p): return f"crosser_loop_classes_{p}"

# %%
cross(test_phase)
# Out:
# 'crosser_loop_scores_NFE2_P3'

# %%
dfs_by_class = {
    lc: subdf
    for lc, subdf in crosser_exploded.groupby(cls(test_phase), dropna=True)
}

for lc, d in dfs_by_class.items():
    d['cross_change'] = d[cross(test_phase)].divide(d[cross(control_phase)])

# %%
agg_by_class = {}

for lc, d in dfs_by_class.items():
    agg = (
        d.groupby(group_cols, as_index=False)
         .agg({
             cross(test_phase): agg_fn,
             cross(control_phase): agg_fn,
         })
    )

    agg_by_class[lc] = agg
    
for lc, d in agg_by_class.items():
    d['cross_change'] = d[cross(test_phase)].divide(d[cross(control_phase)])
# Out:
# /tmp/ipykernel_835450/1668141599.py:5: FutureWarning: The provided callable <function max at 0x7f1cac0dda60> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   d.groupby(group_cols, as_index=False)
# /tmp/ipykernel_835450/1668141599.py:5: FutureWarning: The provided callable <function max at 0x7f1cac0dda60> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   d.groupby(group_cols, as_index=False)
# /tmp/ipykernel_835450/1668141599.py:5: FutureWarning: The provided callable <function max at 0x7f1cac0dda60> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   d.groupby(group_cols, as_index=False)
# ...

# %%
agg_by_class['CTCF-CTCF']
# Out:
#       chr        coord  triangle_fc crosser_loop_scores_NFE2_P3  \
# 0    chr1    8005415.5     0.970893                     1.39833
# 1    chr1    8873774.5     0.814485                    3.102406
# 2    chr1    9717799.0     0.934161                    4.715728
# 3    chr1    9719159.0     0.941179                    4.715728
# 4    chr1   12218650.0     1.025888                    2.875765
# ..    ...          ...          ...                         ...
# 582  chr9  136190423.0     1.037453                     2.75656
# 583  chrX   15580118.0     1.038170                    5.179402
# 584  chrX   41067978.0     0.937371                    9.968207
# 585  chrX  103098677.0     0.939852                   10.415505
# 586  chrX  103099459.0     0.939852                   10.415505
#
#     crosser_loop_scores_AAVS1_P3 cross_change
# 0                       1.429741      0.97803
# 1                       4.015628     0.772583
# 2                       6.071692     0.776674
# ...

# %%
for clas in ['E-P', 'E-E', 'P-P', 'E-CTCF', 'P-CTCF', 'CTCF-CTCF']:
    plt.scatter(agg_by_class[clas].cross_change, agg_by_class[clas].triangle_fc, label=clas, alpha=0.3)
    plt.xlim(0.5, 1.5)
    plt.ylim(0.8, 1.2)
    plt.show()

# %%
agg_by_class['E-P']
# Out:
#       chr        coord  triangle_fc crosser_loop_scores_NFE2_P3  \
# 0    chr1    2290745.5     1.030939                    15.59581
# 1    chr1   12449100.5     1.009189                    7.196713
# 2    chr1   12528757.0     1.012486                    7.196713
# 3    chr1   12529568.0     1.012486                    7.196713
# 4    chr1   18909075.0     1.019888                    3.051105
# ..    ...          ...          ...                         ...
# 703  chrX   77924665.0     0.973347                    2.843957
# 704  chrX  107677252.0     0.965356                    6.783151
# 705  chrX  110178705.0     0.928125                    5.898493
# 706  chrX  110294343.5     0.972799                   24.080091
# 707  chrX  136885069.0     0.989285                    3.671205
#
#     crosser_loop_scores_AAVS1_P3 cross_change
# 0                       14.42668     1.081039
# 1                       7.252507     0.992307
# 2                       7.252507     0.992307
# ...

# %%
nfe_bed_strict = pd.read_csv('/mnt/md0/varshini/Analysis/Blood/other_datasets/NFE2/NFE2_K562_enotpnotc_clean.bed', sep='\t',
                      names=['chr','start','end'])

# %%
nfe_bed_strict
# Out:
#         chr      start        end
# 0      chr7  130026007  130026288
# 1      chr4    8303580    8303973
# 2      chr1   31170852   31171138
# 3      chr7  101100117  101100475
# 4      chr1   32725209   32725513
# ...     ...        ...        ...
# 3794  chr20     728512     728536
# 3795   chr8   49110498   49110762
# 3796   chr7    2019016    2019280
# 3797   chr6   37128768   37129032
# 3798  chr20   64221389   64221653
#
# [3799 rows x 3 columns]

# %%
for i in range(5, 10):
        plot_peak(merged_df.sort_values(by='triangle_fc').iloc[i,:], nfe2_ko, flank=200_000, res=5000, toplot=nfe_bed_strict)
        plt.show()
        plot_peak(merged_df.sort_values(by='triangle_fc').iloc[i,:], nfe2_aavs1, flank=200_000, res=5000, toplot=nfe_bed_strict)
        plt.show()
# Out:
#        chr     start       end
# 471  chr15  58332236  58332491
# chr15:58132363-58532363
#        chr     start       end
# 471  chr15  58332236  58332491
# chr15:58132363-58532363
#        chr      start        end
# 1354  chr3  125496831  125496949
# 1383  chr3  125633110  125633374
# chr3:125433242-125833242
#        chr      start        end
# 1354  chr3  125496831  125496949
# 1383  chr3  125633110  125633374
# chr3:125433242-125833242
#        chr    start      end
# 576   chr1  8873666  8873883
# 2207  chr1  8789342  8789606
# chr1:8673774-9073774
#        chr    start      end
# 576   chr1  8873666  8873883
# 2207  chr1  8789342  8789606
# chr1:8673774-9073774
#         chr      start        end
# 2741  chr10  125921432  125921696
# 3534  chr10  125913378  125913642
# chr10:125721564-126121564
#         chr      start        end
# 2741  chr10  125921432  125921696
# 3534  chr10  125913378  125913642
# chr10:125721564-126121564
#        chr     start       end
# ...

# %% [markdown]
# ## What classes of loops are changing the most? Are they SS or crosser loops?

# %%
import re
from collections import Counter
nquant=5

for loop_type in ['ss', 'crosser']:
    merged_df_sub = merged_df.sort_values(by=f"{loop_type}_fc", ascending=False).dropna(subset=f"{loop_type}_fc")
    # rank the loops by fc for each type. 
    merged_df_sub[f'quantile'] = pd.qcut(merged_df_sub[f"{loop_type}_fc"], nquant, labels=False)
    quantile_dict = {}
    # count the number of each loop class by concatenating all the loop class lists 
    for quant in range(0, nquant):
        df_quant = merged_df_sub[merged_df_sub['quantile']==quant]
#         print((df_quant[f"{loop_type}_loop_classes_{control_phase}"]))
        
        class_list = []
        for elt in df_quant[f"{loop_type}_loop_classes_{control_phase}"].tolist():                
            #print(elt.split("[")[1].split("]")[-2].split(','))
            eltlist = elt.split("[")[1].split("]")[-2].split(',')
            cleaned_list = [re.sub('[^A-Za-z0-9]+', '', mystring) for mystring in eltlist]
            class_list.extend(cleaned_list)
#         print(dict(Counter(class_list)))
        quantile_dict[quant] = dict(Counter(class_list))

        # with pandas
    df = pd.DataFrame.from_dict(quantile_dict, orient='index')
    df = df.div(df.sum(axis=1), axis=0)

    # custom colors, if desired

    # plot
#     ax = df.plot(kind='bar', rot=0, title='Loop Classes by Changing Quantile', width=0.85,
#                  figsize=(8, 5), xlabel='Category', ylabel='Quantity')
    ax = df.plot.bar(stacked=True)
    # cosmetic formatting
    ax.legend(bbox_to_anchor=(1, 0.5), loc='center left', frameon=False)
    ax.spines[['right', 'top']].set_visible(False)

    # iterate through the containers associated with the axes (ax)
    for c in ax.containers:
        ax.bar_label(c, fmt=lambda x: f'{x:0.0f}' if x > 0 else '')
        # make bar plots for each quantile?
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 18
#      15 class_list = []
#      16 for elt in df_quant[f"{loop_type}_loop_classes_{control_phase}"].tolist():
#      17     #print(elt.split("[")[1].split("]")[-2].split(','))
# ---> 18     eltlist = elt.split("[")[1].split("]")[-2].split(',')
#      19     cleaned_list = [re.sub('[^A-Za-z0-9]+', '', mystring) for mystring in eltlist]
#      20     class_list.extend(cleaned_list)
#
# AttributeError: 'list' object has no attribute 'split'

# %%
import re
from collections import Counter
nquant=5

for loop_type in ['ss', 'crosser']:
    merged_df_sub = merged_df.sort_values(by=f"triangle_fc", ascending=False).dropna(subset=f"{loop_type}_fc")
    # rank the loops by fc for each type. 
    merged_df_sub[f'quantile'] = pd.qcut(merged_df_sub[f"triangle_fc"], nquant, labels=False)
    quantile_dict = {}
    # count the number of each loop class by concatenating all the loop class lists 
    for quant in range(0, nquant):
        df_quant = merged_df_sub[merged_df_sub['quantile']==quant]
#         print((df_quant[f"{loop_type}_loop_classes_{control_phase}"]))
        
        class_list = []
        for elt in df_quant[f"{loop_type}_loop_classes_{control_phase}"].tolist():                
            #print(elt.split("[")[1].split("]")[-2].split(','))
            eltlist = elt.split("[")[1].split("]")[-2].split(',')
            cleaned_list = [re.sub('[^A-Za-z0-9]+', '', mystring) for mystring in eltlist]
            class_list.extend(cleaned_list)
#         print(dict(Counter(class_list)))
        quantile_dict[quant] = dict(Counter(class_list))

        # with pandas
    df = pd.DataFrame.from_dict(quantile_dict, orient='index')
    df = df.div(df.sum(axis=1), axis=0)

    # custom colors, if desired

    # plot
#     ax = df.plot(kind='bar', rot=0, title='Loop Classes by Changing Quantile', width=0.85,
#                  figsize=(8, 5), xlabel='Category', ylabel='Quantity')
    ax = df.plot.bar(stacked=True)
    # cosmetic formatting
    ax.legend(bbox_to_anchor=(1, 0.5), loc='center left', frameon=False)
    ax.spines[['right', 'top']].set_visible(False)

    # iterate through the containers associated with the axes (ax)
#     for c in ax.containers:
#         ax.bar_label(c, fmt=lambda x: f'{x:0.0f}' if x > 0 else '')
        # make bar plots for each quantile?
    plt.show()

# %%
df
# Out:
#          EP        PP     PCTCF  CTCFCTCF  NullNull     PNull     ECTCF  \
# 0  0.203488  0.180233  0.191860  0.110465  0.075581  0.098837  0.029070
# 1  0.194286  0.217143  0.137143  0.080000  0.028571  0.091429  0.062857
# 2  0.226415  0.207547  0.113208  0.113208  0.028302  0.070755  0.084906
# 3  0.240838  0.209424  0.089005  0.078534  0.015707  0.041885  0.089005
# 4  0.227848  0.145570  0.151899  0.126582  0.044304  0.069620  0.063291
#
#    CTCFNull     ENull        EE
# 0  0.052326  0.023256  0.034884
# 1  0.022857  0.045714  0.120000
# 2  0.042453  0.037736  0.075472
# 3  0.047120  0.052356  0.136126
# 4  0.069620  0.025316  0.075949

# %%
import re
from collections import Counter
nquant=5

for loop_type in ['ss', 'crosser']:
    merged_df_sub = merged_df.sort_values(by=f"triangle_score_{control_phase}").dropna(subset=f"triangle_score_{test_phase}")
    # rank the loops by fc for each type. 
    merged_df_sub[f'quantile'] = pd.qcut(merged_df_sub[f"triangle_score_{test_phase}"], nquant, labels=False)
    quantile_dict = {}
    # count the number of each loop class by concatenating all the loop class lists 
    for quant in range(0, nquant):
        df_quant = merged_df_sub[merged_df_sub['quantile']==quant]
#         print((df_quant[f"{loop_type}_loop_classes_{control_phase}"]))
        
        class_list = []
        for elt in df_quant[f"{loop_type}_loop_classes_{control_phase}"].tolist():                
            #print(elt.split("[")[1].split("]")[-2].split(','))
            eltlist = elt.split("[")[1].split("]")[-2].split(',')
            #print(eltlist)

            cleaned_list = [re.sub('[^A-Za-z0-9]+', '', mystring) for mystring in eltlist]
            cleaned_list = [mystr for mystr in cleaned_list if mystr!='']
            #print(cleaned_list)
            class_list.extend(cleaned_list)
        print(dict(Counter(class_list)))
        quantile_dict[quant] = dict(Counter(class_list))

        # with pandas
    df = pd.DataFrame.from_dict(quantile_dict, orient='index')
    df = df.div(df.sum(axis=1), axis=0)
    print(df)
    # custom colors, if desired

    # plot
#     ax = df.plot(kind='bar', rot=0, title='Loop Classes by Changing Quantile', width=0.85,
#                  figsize=(8, 5), xlabel='Category', ylabel='Quantity')
    ax = df.plot.bar(stacked=True, figsize=(10,10))
    # cosmetic formatting
    ax.legend(bbox_to_anchor=(1, 0.5), loc='center left', frameon=False)
    ax.spines[['right', 'top']].set_visible(False)

    # iterate through the containers associated with the axes (ax)
#     for c in ax.containers:
#         ax.bar_label(c, fmt=lambda x: f'{x:0.0f}' if x > 0 else '')
        # make bar plots for each quantile?
    plt.show()
# Out:
# {'ECTCF': 12, 'EP': 55, 'PCTCF': 27, 'PNull': 7, 'ENull': 10, 'CTCFNull': 8, 'EE': 16, 'CTCFCTCF': 12, 'PP': 37, 'NullNull': 5}
# {'NullNull': 5, 'EP': 42, 'PNull': 7, 'CTCFCTCF': 7, 'ECTCF': 6, 'PCTCF': 10, 'PP': 37, 'ENull': 3, 'EE': 12, 'CTCFNull': 3}
# {'EP': 26, 'PP': 38, 'PCTCF': 8, 'ECTCF': 5, 'NullNull': 3, 'CTCFCTCF': 9, 'EE': 8, 'ENull': 4, 'PNull': 8}
# {'PCTCF': 11, 'PP': 20, 'EP': 26, 'NullNull': 3, 'EE': 13, 'CTCFCTCF': 2, 'ENull': 4, 'PNull': 3, 'ECTCF': 4, 'CTCFNull': 2}
# {'PCTCF': 16, 'EP': 53, 'ECTCF': 13, 'CTCFNull': 6, 'EE': 27, 'NullNull': 4, 'PNull': 9, 'ENull': 10, 'CTCFCTCF': 9, 'PP': 29}
#       ECTCF        EP     PCTCF     PNull     ENull  CTCFNull        EE  \
# 0  0.063492  0.291005  0.142857  0.037037  0.052910  0.042328  0.084656
# 1  0.045455  0.318182  0.075758  0.053030  0.022727  0.022727  0.090909
# 2  0.045872  0.238532  0.073394  0.073394  0.036697       NaN  0.073394
# 3  0.045455  0.295455  0.125000  0.034091  0.045455  0.022727  0.147727
# ...
